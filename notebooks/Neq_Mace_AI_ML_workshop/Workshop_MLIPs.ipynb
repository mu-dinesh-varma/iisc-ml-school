# %% [markdown]
# # Equivariant Machine Learned Interatomic Potentials Models
#
# Created by ***Debsundar Dey*** and ***Tejus Rohatgi***
#
# This tutorial aims to demonstrate two state-of-the-art MLIP models, **NequIP** and **MACE**.

# %% [markdown]
# # Table of Contents
# 0. [Before Starting](#prep)
# 1. [Dataset](#dataset)
#     *   [BOTNET Dataset](#botnet)
#     *   [Visualising Dataset](#visualise)
# 2. [NequIP](#nequip)
#     * [Introduction](#nequip-intro)
#     * [Installing NequIP](#nequip-install)
#     * [Configuration](#nequip-config)
#     * [Training NequIP](#nequip-training)
#     * [Molecular Dynamics using NequIP](#nequip-md)
# 3. [MACE](#mace)
#     * [Introduction](#mace-intro)
#     * [Installing MACE](#mace-install)
#     * [Configuration](#mace-config)
#     * [Training MACE](#mace-training)
#     * [Molecular Dynamics using MACE](#mace-md)
# 4. [Exercises](#exercises)
# 5. [BONUS: Visualizing `.xyz` files](#ovito)

# %% [markdown]
# ## 0. Before Starting <a name="prep"></a>

# %%
# Install necessary packages
# !pip install ase
# Out:
# Collecting ase
#   Downloading ase-3.24.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from ase) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from ase) (1.13.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.10/dist-packages (from ase) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase) (1.17.0)
# Downloading ase-3.24.0-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 22.0 MB/s eta 0:00:00
# Installing collected packages: ase
# Successfully installed ase-3.24.0

# %%
# Import necessary libraries
import os
from pathlib import Path
import yaml
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import ase
import random
import time
import pylab as pl
import torch

random.seed(123)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device.type
# Out:
# 'cpu'

# %% [markdown]
# # 1. Dataset <a name="dataset"></a>
# The dataset plays a crucial role in training and evaluating Machine Learning Interatomic Potential (MLIP) models. Its quality, diversity, and relevance significantly impact the performance and generalizability of the MLIP. The dataset provides the atomic configurations and corresponding properties (e.g., energy, forces, stress) that the MLIP aims to predict.
#
# ## 1.1. BOTNET Dataset <a name="botnet"></a>
# We will be working on the [BOTNET](https://github.com/davkovacs/BOTNet-datasets) collection of dataset used in the paper by [Batatia et.al](https://arxiv.org/abs/2205.06643). The collection contains the following datasets:
#
# 1. **Ethanol and Methanol:** Consists of two training datasets, first taken revMD17 dataset and was sampled from a long 500 K Ab Initio molecular dynamics trajectory and the second training set contains the 1000 ethanol geometries of the first training set but is augmented by 300 K methanol geometries also sampled from 500 K Ab Initio molecular dynamics simulation.
# 2. **3BPA:** Dataset contains snapshots of a large flexible drug-like organic molecule sampled from different temperature molecular dynamics trajectories.
# 3. **Acetylacetone:** Dataset contains data related to acetylacetone (acac), specifically focusing on proton transfer reactions between its tautomeric forms. This dataset includes configurations obtained from Ab Initio molecular dynamics simulations at 300 K.

# %%
# Downloading BOTNet Datset
# !git clone https://github.com/davkovacs/BOTNet-datasets.git
# Out:
# Cloning into 'BOTNet-datasets'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 57 (delta 13), reused 37 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 28.73 MiB | 25.06 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# !ls BOTNet-datasets/dataset_ethanol
# Out:
# isolated_atoms.xyz  test_eth_meth.xyz	test_norm_mode_3005.xyz  train.xyz
# README.md	    test_H_removal.xyz	test_norm_mode_874.xyz
# test_dimers.xyz     test_MD.xyz		train_eth_meth.xyz

# %%
# !ls BOTNet-datasets/dataset_3BPA
# Out:
# iso_atoms.xyz  test_1200K.xyz  test_600K.xyz  train_300K.xyz
# README.md      test_300K.xyz   test_dih.xyz   train_mixedT.xyz

# %%
# !ls BOTNet-datasets/dataset_acac
# Out:
# isolated_atoms.xyz  test_dihedral.xyz	 test_MD_300K.xyz  train_300K.xyz
# README.md	    test_H_transfer.xyz  test_MD_600K.xyz  train_600K.xyz

# %% [markdown]
# We will be working with **[3BPA dataset](https://github.com/davkovacs/BOTNet-datasets/tree/main/dataset_3BPA)**:

# %% [markdown]
# ### 1.2. Visualising Dataset <a name="visualise"></a>

# %%
from ase.io import read, write

# Load the dataset
dataset = read("BOTNet-datasets/dataset_3BPA/train_mixedT.xyz", index=":")
dataset[0]
# Out:
# Atoms(symbols='C3HCON2H2CH2C2H2C3HCHCH3', pbc=False, cell=[50.0, 50.0, 50.0], calculator=SinglePointCalculator(...))

# %%
num_configs = len(dataset)
print(f"Number of configurations in the dataset: {num_configs}")
# Out:
# Number of configurations in the dataset: 500

# %%
from ase.visualize.plot import plot_atoms

# Visualize the atomic structure
fig, ax = plt.subplots()
plot_atoms(dataset[0], ax,
          #  rotation=('30y')
           )
plt.axis('off')
plt.xlim(0, 15) # To zoom
plt.ylim(0, 15) # To zoom
plt.show()

# %% [markdown]
# ## 2. NequIP <a name="nequip"></a>
# ### 2.1. Introduction <a name="nequip-intro"></a>
#
# Welcome to the *NequIP Tutorial with Molecular Dynamics*, where we’ll train a NequIP model with AIMD data and use it for MD simulations! Think of this as a speedrun through the molecular jungle—we might skip some scenic routes (a.k.a. deep physical intuition), but we’ll get you to the finish line with a working model. So buckle up, and let’s dive into the NequIPverse.
#
# #### About NequIP
#
# NequIP employs E(3)-equivariant graph neural networks, which respect the symmetries of three-dimensional Euclidean space (rotations, translations, and reflections). This allows the model to learn both scalar (e.g., energy) and vector (e.g., forces) properties in a symmetry-aware manner.

# %% [markdown]
# ### 2.2. Installing NequIP <a name="nequip-install"></a>

# %%
# Clone NequIP
# !git clone https://github.com/mir-group/nequip.git

# Install NequIP
# !cd nequip && pip install .
# Out:
# Cloning into 'nequip'...
# remote: Enumerating objects: 14008, done.
# remote: Counting objects: 100% (4353/4353), done.
# remote: Compressing objects: 100% (558/558), done.
# remote: Total 14008 (delta 4033), reused 3905 (delta 3795), pack-reused 9655 (from 2)
# Receiving objects: 100% (14008/14008), 3.88 MiB | 21.00 MiB/s, done.
# Resolving deltas: 100% (10180/10180), done.
# Processing /content/nequip
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nequip==0.6.1) (1.26.4)
# Requirement already satisfied: ase in /usr/local/lib/python3.10/dist-packages (from nequip==0.6.1) (3.24.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nequip==0.6.1) (4.67.1)
# Collecting e3nn<0.6.0,>=0.4.4 (from nequip==0.6.1)
#   Downloading e3nn-0.5.4-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from nequip==0.6.1) (6.0.2)
# Collecting torch-runstats>=0.2.0 (from nequip==0.6.1)
#   Downloading torch_runstats-0.2.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting torch-ema>=0.3.0 (from nequip==0.6.1)
#   Downloading torch_ema-0.3-py3-none-any.whl.metadata (415 bytes)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (1.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (2.5.1+cu121)
# Collecting opt-einsum-fx>=0.1.4 (from e3nn<0.6.0,>=0.4.4->nequip==0.6.1)
#   Downloading opt_einsum_fx-0.1.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.10/dist-packages (from ase->nequip==0.6.1) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (2.8.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from opt-einsum-fx>=0.1.4->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (3.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (2024.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase->nequip==0.6.1) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (3.0.2)
# Downloading e3nn-0.5.4-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.2/447.2 kB 12.0 MB/s eta 0:00:00
# Downloading torch_ema-0.3-py3-none-any.whl (5.5 kB)
# Downloading torch_runstats-0.2.0-py3-none-any.whl (8.1 kB)
# Downloading opt_einsum_fx-0.1.4-py3-none-any.whl (13 kB)
# Building wheels for collected packages: nequip
#   Building wheel for nequip (setup.py) ... done
#   Created wheel for nequip: filename=nequip-0.6.1-py3-none-any.whl size=175386 sha256=ed19d7b2c30706bb699a494972912c6e6bc5f06493b4dd8a3b0051efa5654543
#   Stored in directory: /tmp/pip-ephem-wheel-cache-82tfswrj/wheels/11/64/44/9d30bacb0803dffa7821bb8685dbc60a0830cca339476e4e86
# Successfully built nequip
# Installing collected packages: torch-runstats, torch-ema, opt-einsum-fx, e3nn, nequip
# Successfully installed e3nn-0.5.4 nequip-0.6.1 opt-einsum-fx-0.1.4 torch-ema-0.3 torch-runstats-0.2.0

# %%
# !ls nequip
# Out:
# build	      configs	       docs	 LICENSE   nequip	    README.md  setup.py
# CHANGELOG.md  CONTRIBUTING.md  examples  logo.png  nequip.egg-info  setup.cfg  tests

# %% [markdown]
# ### 2.3. Configuration <a name="nequip-config"></a>

# %%
# Specify Paths
nequip_dir = Path(os.getcwd()) / 'nequip'
nequip_configs_dir = nequip_dir / 'configs'
nequip_results_dir = nequip_dir / 'results'

# Create directories if not exists
os.makedirs(nequip_configs_dir, exist_ok=True)
os.makedirs(nequip_results_dir, exist_ok=True)

# %% [markdown]
# #### 2.3.1. Hyperparameters in Training NequIP <a name="nequip-hypparam"></a>

# %%
# Specifying parameters for training a NequIP model

parameters_nequip = {

    # Specify model name and save directories
    "root": str(nequip_results_dir),
    "run_name": "botnet",

    # Dataset
    "dataset": "ase",
    "dataset_file_name": "BOTNet-datasets/dataset_3BPA/train_mixedT.xyz",

    "key_mapping": {
        "z": "atomic_numbers",
        "E": "total_energy",
        "F": "forces",
        "R": "pos",
    },
    "chemical_symbols": ["H", "O", "C", "N"],

    # Hyperparameters
    "num_features": 64, # Number of channels determining the size of the model
    "r_max": 4.0,  # Maximum interaction radius
    "l_max": 1, # Symmetry of messages
    "parity": "true", # whether to include features with odd mirror parity
    "num_layers": 4,  # Number of message-passing layers in the model
    # radial network
    "num_basis": 8, # number of basis functions used in the radial basis, 8 usually works best
    "invariant_layers": 2, # number of radial layers, usually 1-3 works best, smaller is faster
    "invariant_neurons": 64,  # number of hidden neurons in radial function, smaller is faster

    # Optimization
    "n_train": "95%", # Fraction of the training set to use as training
    "n_val": "5%", # Fraction of the training set to use as validation
    "batch_size": 10, # Batch size for training
    "max_epochs": 20, # Maximum number of epochs
    "default_dtype": "float64", # Precision for calculations
    "model_dtype": "float32",
    "wandb": False, # Logging
    "device": device.type, # Device to use ("cuda" for GPU)
    "seed": 123,
    "dataset_seed": 456,
}


# Save parameters to a YAML file
input_nequip = nequip_configs_dir / "input.yaml"

with open(input_nequip, "w") as file:
    yaml.dump(parameters_nequip, file, default_flow_style=False)

# Remove run_name if exists


print(f"Parameters have been saved to {input_nequip}")
# Out:
# Parameters have been saved to /content/nequip/configs/input.yaml

# %% [markdown]
# ### 2.4. Training NequIP <a name="nequip-train"></a>
#
# To train a MACE model, you can use the `nequip-train` file.

# %%
# !nequip-train --help
# Out:
# /usr/local/lib/python3.10/dist-packages/nequip/__init__.py:20: UserWarning: !! PyTorch version 2.5.1 found. Upstream issues in PyTorch versions 1.13.* and 2.* have been seen to cause unusual performance degredations on some CUDA systems that become worse over time; see https://github.com/mir-group/nequip/discussions/311. The best tested PyTorch version to use with CUDA devices is 1.11; while using other versions if you observe this problem, an unexpected lack of this problem, or other strange behavior, please post in the linked GitHub issue.
#   warnings.warn(
# usage: nequip-train [-h] [--equivariance-test [EQUIVARIANCE_TEST]] [--model-debug-mode]
#                     [--grad-anomaly-mode] [--gpu-oom-offload] [--log LOG] [--warn-unused]
#                     config
#
# Train (or restart training of) a NequIP model.
#
# positional arguments:
#   config                YAML file configuring the model, dataset, and other options
#
# options:
#   -h, --help            show this help message and exit
#   --equivariance-test [EQUIVARIANCE_TEST]
#                         test the model's equivariance before training on n (default 1) random
#                         frames from the dataset
#   --model-debug-mode    enable model debug mode, which can sometimes give much more useful error
#                         messages at the cost of some speed. Do not use for production training!
#   --grad-anomaly-mode   enable PyTorch autograd anomaly mode to debug NaN gradients. Do not use
#                         for production training!
#   --gpu-oom-offload     Use `torch.autograd.graph.save_on_cpu` to offload intermediate tensors to
#                         CPU (host) memory in order to train models that would be impossible
#                         otherwise due to OOM. Note that this comes as at a speed cost and SHOULD
#                         NOT be used if your training fits in GPU memory without it. Please also
#                         consider whether a smaller model is a more appropriate solution.
#   --log LOG             log file to store all the screen logging
#   --warn-unused         Warn instead of error when the config contains unused keys

# %%
# !nequip-train nequip/configs/input.yaml
# Out:
# /usr/local/lib/python3.10/dist-packages/nequip/__init__.py:20: UserWarning: !! PyTorch version 2.5.1 found. Upstream issues in PyTorch versions 1.13.* and 2.* have been seen to cause unusual performance degredations on some CUDA systems that become worse over time; see https://github.com/mir-group/nequip/discussions/311. The best tested PyTorch version to use with CUDA devices is 1.11; while using other versions if you observe this problem, an unexpected lack of this problem, or other strange behavior, please post in the linked GitHub issue.
#   warnings.warn(
# Torch device: cpu
# Processing dataset...
# /usr/local/lib/python3.10/dist-packages/nequip/__init__.py:20: UserWarning: !! PyTorch version 2.5.1 found. Upstream issues in PyTorch versions 1.13.* and 2.* have been seen to cause unusual performance degredations on some CUDA systems that become worse over time; see https://github.com/mir-group/nequip/discussions/311. The best tested PyTorch version to use with CUDA devices is 1.11; while using other versions if you observe this problem, an unexpected lack of this problem, or other strange behavior, please post in the linked GitHub issue.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/nequip/__init__.py:20: UserWarning: !! PyTorch version 2.5.1 found. Upstream issues in PyTorch versions 1.13.* and 2.* have been seen to cause unusual performance degredations on some CUDA systems that become worse over time; see https://github.com/mir-group/nequip/discussions/311. The best tested PyTorch version to use with CUDA devices is 1.11; while using other versions if you observe this problem, an unexpected lack of this problem, or other strange behavior, please post in the linked GitHub issue.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/nequip/utils/_global_options.py:95: UserWarning: Do NOT manually set PYTORCH_JIT_USE_NNC_NOT_NVFUSER=0 unless you know exactly what you're doing!
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/nequip/utils/_global_options.py:95: UserWarning: Do NOT manually set PYTORCH_JIT_USE_NNC_NOT_NVFUSER=0 unless you know exactly what you're doing!
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/nequip/data/_dataset/_ase_dataset.py:231: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   datas = [torch.load(d) for d in datas]
# Loaded data: Batch(atomic_numbers=[13500, 1], batch=[13500], cell=[500, 3, 3], edge_cell_shift=[162200, 3], edge_index=[2, 162200], forces=[13500, 3], pbc=[500, 3], pos=[13500, 3], ptr=[501], total_energy=[500, 1])
#     processed data size: ~7.05 MB
# Cached processed data to disk
# Done!
# Successfully loaded the data set of type ASEDataset(500)...
# Replace string dataset_per_atom_total_energy_mean to -654.0413538809098
# Atomic outputs are scaled by: [H, C, N, O: None], shifted by [H, C, N, O: -654.041354].
# Replace string dataset_forces_rms to 1.4213799318595246
# Initially outputs are globally scaled by: 1.4213799318595246, total_energy are globally shifted by None.
# Successfully built the network...
# Number of weights: 598312
# Number of trainable weights: 598312
# ! Starting training ...
#
# validation
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       0     5            1            1          1.4         1.42
#
#
#   Initialization     #    Epoch      wal       LR       loss_e         loss        e_mae       e_rmse
# ! Initial Validation          0    2.577     0.01        0.812        0.812        0.979         1.28
# Wall time: 2.57791122499998
# ! Best model        0    0.812
#
# training
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       1    48         1.22         1.22         1.27         1.57
#
# validation
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       1     5         1.07         1.07         1.47         1.47
#
#
#   Train      #    Epoch      wal       LR       loss_e         loss        e_mae       e_rmse
# ! Train               1   53.847     0.01        0.977        0.977         1.17          1.4
# ! Validation          1   53.847     0.01        0.815        0.815         1.06         1.28
# Wall time: 53.84739320299997
#
# training
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       2    48        0.696        0.696         1.14         1.19
#
# validation
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       2     5         1.01         1.01         1.42         1.43
#
#
#   Train      #    Epoch      wal       LR       loss_e         loss        e_mae       e_rmse
# ! Train               2  102.346     0.01        0.882        0.882         1.15         1.34
# ! Validation          2  102.346     0.01        0.799        0.799            1         1.27
# Wall time: 102.34684740299997
# ! Best model        2    0.799
#
# training
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       3    48        0.448        0.448        0.877        0.952
#
# validation
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       3     5        0.149        0.149        0.506        0.549
#
#
#   Train      #    Epoch      wal       LR       loss_e         loss        e_mae       e_rmse
# ! Train               3  151.855     0.01        0.743        0.743         1.02         1.23
# ! Validation          3  151.855     0.01        0.207        0.207        0.492        0.646
# Wall time: 151.85548720399993
# ! Best model        3    0.207
#
# training
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       4    48        0.301        0.301        0.715         0.78
#
# validation
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       4     5       0.0413       0.0413        0.196        0.289
#
#
#   Train      #    Epoch      wal       LR       loss_e         loss        e_mae       e_rmse
# ! Train               4  207.286     0.01        0.427        0.427        0.717        0.931
# ! Validation          4  207.286     0.01        0.112        0.112        0.358        0.475
# Wall time: 207.286564043
# ! Best model        4    0.112
#
# training
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       5    48        0.145        0.145        0.392        0.542
#
# validation
# # Epoch batch         loss       loss_e        e_mae       e_rmse
#       5     5        0.168        0.168        0.537        0.582
#
#
#   Train      #    Epoch      wal       LR       loss_e         loss        e_mae       e_rmse
# ! Train               5  258.518     0.01        0.219        0.219        0.518        0.666
# ! Validation          5  258.518     0.01        0.132        0.132         0.41        0.517
# Wall time: 258.518329376
#
# training
# # Epoch batch         loss       loss_e        e_mae       e_rmse
# Traceback (most recent call last):
#   File "/usr/local/bin/nequip-train", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/nequip/scripts/train.py", line 115, in main
#     trainer.train()
#   File "/usr/local/lib/python3.10/dist-packages/nequip/train/trainer.py", line 784, in train
#     self.epoch_step()
#   File "/usr/local/lib/python3.10/dist-packages/nequip/train/trainer.py", line 919, in epoch_step
#     self.batch_step(
#   File "/usr/local/lib/python3.10/dist-packages/nequip/train/trainer.py", line 814, in batch_step
#     out = self.model(data_for_loss)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/nequip/nn/_graph_model.py", line 112, in forward
#     data = self.model(new_data)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/nequip/nn/_rescale.py", line 144, in forward
#     data = self.model(data)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/nequip/nn/_grad_output.py", line 310, in forward
#     grads = torch.autograd.grad(
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py", line 496, in grad
#     result = _engine_run_backward(
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py", line 825, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt

# %% [markdown]
# **Extra:** Try running the model with different hyperparameters.

# %%
# Check the output files
nequip_train_dir = nequip_results_dir / Path(parameters_nequip["run_name"])
for file in nequip_train_dir.rglob("*"):
    print(file)
# Out:
# /content/nequip/results/botnet/trainer.pth
# /content/nequip/results/botnet/best_model.pth
# /content/nequip/results/botnet/metrics_batch_val.csv
# /content/nequip/results/botnet/last_model.pth
# /content/nequip/results/botnet/metrics_epoch.csv
# /content/nequip/results/botnet/config.yaml
# /content/nequip/results/botnet/metrics_batch_train.csv
# /content/nequip/results/botnet/metrics_initialization.csv
# /content/nequip/results/botnet/log

# %% [markdown]
# Check the file saved as `metric_epoch.csv` for information of about training.

# %%
nequip_train_csv = nequip_train_dir / "metrics_epoch.csv"

# Load the CSV file
df = pd.read_csv(nequip_train_csv)

df.head()
# Out:
#    epoch    wall    LR  training_loss_e  training_loss  training_e_mae  \
# 0      1   9.957  0.01          0.97736        0.97736           1.170
# 1      2  13.556  0.01          0.88154        0.88154           1.150
# 2      3  18.014  0.01          0.74266        0.74266           1.020
# 3      4  21.593  0.01          0.42724        0.42724           0.717
# 4      5  25.180  0.01          0.21894        0.21894           0.518
#
#    training_e_rmse  validation_loss_e  validation_loss  validation_e_mae  \
# 0            1.400            0.81472          0.81472             1.060
# 1            1.340            0.79868          0.79868             1.000
# 2            1.230            0.20658          0.20658             0.492
# 3            0.931            0.11165          0.11165             0.358
# 4            0.666            0.13238          0.13238             0.410
#
#    validation_e_rmse
# 0              1.280
# 1              1.270
# 2              0.646
# 3              0.475
# 4              0.517

# %%
# Columns to plot
metrics = [
    'training_loss_e',
    'training_loss',
    'training_e_mae',
    'training_e_rmse',
    'validation_loss_e',
    'validation_loss',
    'validation_e_mae',
    'validation_e_rmse',
    ]

# Plot each metric against the epoch
plt.figure(figsize=(10, 6))
for metric in df.columns:
    if metric in metrics:
        plt.plot(df['epoch'], df[metric], label=metric)

# Add labels, title, and legend
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.title('NequIP Training')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### 2.5. Molecular Dynamics using NequIP <a name="nequip-md"></a>

# %% [markdown]
# Molecular dynamics (MD) is a computer simulation technique used to model and analyze the physical movements of atoms and molecules over time. By applying the principles of classical mechanics, specifically Newton's equations of motion, MD calculates the trajectories of particles based on the forces acting between them. These forces are typically derived from potential energy functions that describe interactions such as bonding, electrostatics, and van der Waals forces. The MLIPs are the potential energy functions we are using here.
#
# We will be using ASE (Atomic Simulation Environment) for performing a simple MD simulations using the module [`ase.md`](https://wiki.fysik.dtu.dk/ase/ase/md.html).

# %% [markdown]
# #### 2.5.1. ASE Molecular Dynamics <a name="nequip-md-ase"></a>

# %%
from ase import units
from ase.md.langevin import Langevin
from ase.md.velocitydistribution import Stationary, ZeroRotation, MaxwellBoltzmannDistribution
from ase.calculators.calculator import Calculator
from IPython import display

def simpleMD(
    init_conf: ase.Atoms,
    temp: float,
    calc: Calculator,
    fname: str,
    s: int,
    T: int,
    seed = 123,
    init_temp = 300,
    friction = 0.1,
    ) -> None:
    """
    Perform a simple molecular dynamics (MD) simulation using the Langevin thermostat.

    Parameters:
    -----------
    init_conf : Initial atomic configuration to start the simulation.
    temp :  Target temperature of the system in Kelvin.
    calc :  Calculator to compute forces and energies for the simulation.
    fname :  Filename to store the trajectory (.xyz format).
    s :  Interval (in steps) to save frames and update the plot.
    T :  Total number of MD steps to run.
    seed: To ensure reproducibiity
    init_temp: Initialization temperature
    friction: Damping factor in Langevin

    Returns: None
    """

    # Assign the calculator for force and energy calculations
    init_conf.set_calculator(calc)

    # Initialize the temperature of the system
    random.seed(123)  # Seed for reproducibility
    MaxwellBoltzmannDistribution(init_conf, temperature_K=init_temp)  # Initial temp 300 K
    Stationary(init_conf)  # Remove net momentum
    ZeroRotation(init_conf)  # Remove angular momentum

    # Set up the Langevin thermostat
    dyn = Langevin(init_conf, 1.0 * units.fs, temperature_K=temp, friction=friction)

    # Required for inline plotting in Jupyter Notebook
    # %matplotlib inline

    # Initialize lists to store time, temperature, and energy
    time_fs = []
    temperature = []
    energies = []

    # Remove any existing trajectory file with the same name
    os.system("rm -rfv " + fname)

    # Create a plot with two subplots
    fig, ax = pl.subplots(2, 1, figsize=(6, 6), sharex="all", gridspec_kw={"hspace": 0, "wspace": 0})

    def write_frame():
        """
        Function to save a frame of the trajectory and update the live plot.
        """
        dyn.atoms.write(fname, append=True)  # Append current configuration to file
        time_fs.append(dyn.get_time() / units.fs)  # Store current simulation time
        temperature.append(dyn.atoms.get_temperature())  # Store current temperature
        energies.append(dyn.atoms.get_potential_energy() / len(dyn.atoms))  # Potential energy per atom

        # Update the plot
        ax[0].plot(np.array(time_fs), np.array(energies), color="b")
        ax[0].set_ylabel("E (eV/atom)")

        ax[1].plot(np.array(time_fs), temperature, color="r")
        ax[1].set_ylabel("T (K)")
        ax[1].set_xlabel("Time (fs)")
        ax[1].set_ylim(ymax = 2.0*temp )

        # Clear the previous plot and display the updated one
        display.clear_output(wait=True)
        display.display(pl.gcf())
        time.sleep(0.01)  # Pause for a short time to make the updates visible

    # Attach the write_frame function to be called every `s` steps
    dyn.attach(write_frame, interval=s)

    # Run the MD simulation and time its execution
    t0 = time.time()
    dyn.run(T)
    t1 = time.time()

    print("MD finished in {0:.2f} minutes!".format((t1 - t0) / 60))

# %% [markdown]
# We use Langevin thermostat using [`ase.md.langevin.Langevin` ](https://wiki.fysik.dtu.dk/ase/ase/md.html#module-ase.md.langevin).
#
# [Langevin dynamics](https://en.wikipedia.org/wiki/Langevin_dynamics) is a computational simulation method used to model the behavior of particles in a system by incorporating both deterministic and stochastic (random) forces. It extends classical molecular dynamics (MD) by introducing additional terms to account for the interaction of particles with their surrounding environment, typically represented as a heat bath. This approach is particularly useful for simulating systems at a constant temperature and for capturing the effects of thermal fluctuations and friction without explicitly modeling every component of the environment.
#
# \begin{equation}
# M \ddot{\mathbf{X}} = -\nabla U(\mathbf{X}) - \gamma M \dot{\mathbf{X}} + \sqrt{2 M \gamma k_{\mathrm{B}} T} \, \mathbf{R}(t),
# \end{equation}

# %% [markdown]
# #### 2.5.2. Deploying NequIP Model <a name="nequip-md-deploy"></a>
# The `nequip-deploy` command is used to deploy the result of a training session into a model that can be stored and used for inference. It compiles a NequIP model trained in Python to TorchScript. The result is an optimized model file that has no dependency on the nequip Python library, or even on Python itself

# %%
# !nequip-deploy --help
# Out:
# /usr/local/lib/python3.10/dist-packages/nequip/__init__.py:20: UserWarning: !! PyTorch version 2.5.1 found. Upstream issues in PyTorch versions 1.13.* and 2.* have been seen to cause unusual performance degredations on some CUDA systems that become worse over time; see https://github.com/mir-group/nequip/discussions/311. The best tested PyTorch version to use with CUDA devices is 1.11; while using other versions if you observe this problem, an unexpected lack of this problem, or other strange behavior, please post in the linked GitHub issue.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# usage: nequip-deploy [-h] [--verbose VERBOSE] {info,build} ...
#
# Deploy and view information about previously deployed NequIP models.
#
# options:
#   -h, --help         show this help message and exit
#   --verbose VERBOSE  log level
#
# commands:
#   {info,build}
#     info             Get information from a deployed model file
#     build            Build a deployment model

# %%
# !nequip-deploy build --train-dir nequip/results/botnet/ nequip/results/botnet/deployed_model.pth
# Out:
# /usr/local/lib/python3.10/dist-packages/nequip/__init__.py:20: UserWarning: !! PyTorch version 2.5.1 found. Upstream issues in PyTorch versions 1.13.* and 2.* have been seen to cause unusual performance degredations on some CUDA systems that become worse over time; see https://github.com/mir-group/nequip/discussions/311. The best tested PyTorch version to use with CUDA devices is 1.11; while using other versions if you observe this problem, an unexpected lack of this problem, or other strange behavior, please post in the linked GitHub issue.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# INFO:root:Loading best_model.pth from training session...
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/nequip/scripts/deploy.py:327: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(
# INFO:root:Compiled & optimized model.

# %% [markdown]
# #### 2.5.3. NequIP Calculator <a name="nequip-md-calc"></a>
# NequIP models can run molecular dynamics or geometry optimisation through the ASE calculator.

# %%
init_conf = read('./BOTNet-datasets/dataset_3BPA/test_1200K.xyz', index=0)
init_conf
# Out:
# Atoms(symbols='C3HCON2H2CH2C2H2C3HCHCH3', pbc=False, cell=[50.0, 50.0, 50.0], calculator=SinglePointCalculator(...))

# %%
from nequip.ase import NequIPCalculator

# Specify the path to the pre-trained MACE model
nequip_model = nequip_train_dir / "deployed_model.pth"

# Initialize the NequIP calculator with the specified model
nequip_calc = NequIPCalculator.from_deployed_model(nequip_model)

# Call the simpleMD function to perform a molecular dynamics simulation
simpleMD(init_conf, temp=1200, calc=nequip_calc, fname='nequip/results/nequip01_md.xyz', s=10, T=1000)
# Out:
# MD finished in 4.21 minutes!

# %% [markdown]
# ## 3. MACE <a name="mace"></a>

# %% [markdown]
# ### 3.1. Introduction <a name="mace-intro"></a>
# #### About MACE
#
# [MACE](https://proceedings.neurips.cc/paper_files/paper/2022/hash/4a36c3c51af11ed9f34615b81edb5bbc-Abstract-Conference.html) is a machine learning interatomic potential (MLIP) framework that leverages **message-passing neural networks (MPNNs)** with equivariant representations to capture **complex many-body interactions** in atomic systems.
#
# Inspired from [ACE](https://doi.org/10.1103/PhysRevB.99.014104)-framework, MACE implements a many-body order basis and combines it with message passing framework similar to NequIP to resulting in a fast and highly parallelizable model, reaching or exceeding state-of-the-art accuracy, reducing the number of message passing iterations to just two. For a deeper dive refer to [this paper](https://arxiv.org/abs/2205.06643).
#
# #### Objective
# This tutorial aims to give a brief introduction to using MACE for training on dataset and implementing a simple Molecular Dynamics code.

# %% [markdown]
# ### 3.2. Installing MACE <a name="mace-install"></a>

# %%
# Install dependencies
# !pip install e3nn==0.4.4 opt_einsum ase torch_ema prettytable

# Clone MACE
# !git clone --depth 1 https://github.com/ACEsuit/mace.git

# Install MACE
# !cd mace && pip install .
# Out:
# Requirement already satisfied: e3nn==0.4.4 in /usr/local/lib/python3.10/dist-packages (0.4.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.10/dist-packages (3.4.0)
# Requirement already satisfied: ase in /usr/local/lib/python3.10/dist-packages (3.24.0)
# Requirement already satisfied: torch_ema in /usr/local/lib/python3.10/dist-packages (0.3)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4) (1.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4) (2.5.1+cu121)
# Requirement already satisfied: opt-einsum-fx>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4) (0.1.4)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from ase) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.10/dist-packages (from ase) (3.8.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable) (0.2.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (2.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn==0.4.4) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn==0.4.4) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn==0.4.4) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn==0.4.4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn==0.4.4) (2024.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->e3nn==0.4.4) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->e3nn==0.4.4) (3.0.2)
# fatal: destination path 'mace' already exists and is not an empty directory.
# Processing /content/mace
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (2.5.1+cu121)
# Requirement already satisfied: e3nn==0.4.4 in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (0.4.4)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (1.26.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (3.4.0)
# Requirement already satisfied: ase in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (3.24.0)
# Requirement already satisfied: torch-ema in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (0.3)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (3.12.0)
# Requirement already satisfied: matscipy in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (1.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (3.12.1)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (1.6.1)
# Requirement already satisfied: python-hostlist in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (2.2.1)
# Requirement already satisfied: configargparse in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (1.7)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (3.1.43)
# Requirement already satisfied: pyYAML in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (4.67.1)
# Requirement already satisfied: cuequivariance-torch in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (0.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (3.8.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.9) (2.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4->mace-torch==0.3.9) (1.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4->mace-torch==0.3.9) (1.13.1)
# Requirement already satisfied: opt-einsum-fx>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4->mace-torch==0.3.9) (0.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch==0.3.9) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch==0.3.9) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch==0.3.9) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch==0.3.9) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch==0.3.9) (2024.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->e3nn==0.4.4->mace-torch==0.3.9) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.9) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.9) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.9) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.9) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.9) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.9) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.9) (2.8.2)
# Requirement already satisfied: cuequivariance in /usr/local/lib/python3.10/dist-packages (from cuequivariance-torch->mace-torch==0.3.9) (0.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython->mace-torch==0.3.9) (4.0.11)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mace-torch==0.3.9) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->mace-torch==0.3.9) (2024.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->mace-torch==0.3.9) (0.2.13)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics->mace-torch==0.3.9) (0.11.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython->mace-torch==0.3.9) (5.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics->mace-torch==0.3.9) (75.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mace-torch==0.3.9) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12->mace-torch==0.3.9) (3.0.2)
# Building wheels for collected packages: mace-torch
#   Building wheel for mace-torch (pyproject.toml) ... done
#   Created wheel for mace-torch: filename=mace_torch-0.3.9-py3-none-any.whl size=151811 sha256=fbc6adba4b59265a24c8d0b52a33f80a0522b2fe833b9475a1a019e97bfd1376
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kp5w6qe0/wheels/df/5f/32/ef59561725170a81c728fd01c75e56a9ee83bad6da485fc6a5
# Successfully built mace-torch
# Installing collected packages: mace-torch
#   Attempting uninstall: mace-torch
#     Found existing installation: mace-torch 0.3.9
#     Uninstalling mace-torch-0.3.9:
#       Successfully uninstalled mace-torch-0.3.9
# Successfully installed mace-torch-0.3.9

# %%
# View MACE directory
# !ls mace
# Out:
# build	 LICENSE.md  mace_torch.egg-info  pyproject.toml  results  setup.cfg
# configs  mace	     MANIFEST.in	  README.md	  scripts  tests

# %% [markdown]
# ### 3.3. Configuration <a name="mace-config"></a>

# %%
# Specify paths
mace_dir = Path(os.getcwd()) / 'mace'
mace_configs_dir = mace_dir / 'configs'
mace_results_dir = mace_dir / 'results'

# Create directories if not exists
os.makedirs(mace_configs_dir, exist_ok=True)
os.makedirs(mace_results_dir, exist_ok=True)

# %% [markdown]
# #### 3.3.1 Hyperparameters in Training MACE
#
# For configuring the hyperparameters, we can specify a YAML file. The following is an example:

# %%
# Specifying parameters for training a MACE model

parameters_mace = {

    # Specify model name and save directories
    "name": "botnet_3bpa",  # Name of the model being trained
    "model_dir": str(mace_results_dir),
    "log_dir": str(mace_results_dir),
    "checkpoints_dir": str(mace_results_dir),
    "results_dir": str(mace_results_dir),

    # Train file specifications
    "train_file": "BOTNet-datasets/dataset_3BPA/train_mixedT.xyz",  # Path to training data
    "forces_key": "forces",  # Key for forces in the dataset
    "energy_key": "energy",  # Key for energy in the dataset

    # From iso_atoms.xyz get the reference energies for isolated atoms.
    "E0s": {
        1: -13.663181292231226,  # Energy for Hydrogen (H)
        6: -1029.2809654211628,  # Energy for Carbon (C)
        7: -1484.1187695035828,  # Energy for Nitrogen (N)
        8: -2042.0330099956639,  # Energy for Oxygen (O)
    },

    # Hyperparameters
    "model": "MACE",  # Type of model to train (https://mace-docs.readthedocs.io/en/latest/guide/training.html#model)
    "num_channels": 64, # Number of channels determining the size of the model
    "r_max": 4.0,  # Maximum interaction radius
    "max_L": 1, # Symmetry of messages

    "num_interactions": 2,  # Number of message-passing layers in the model (recommended to keep default)
    "correlation": 3, # The order of the many-body expansion (recommended to keep default)
    "max_ell": 3, # The angular resolution describes how well the model can describe angles (recommended to keep default)

    # Optimization
    "valid_fraction": 0.05, # Fraction of the training set to use as validation
    "batch_size": 10, # Batch size for training
    "max_num_epochs": 20, # Maximum number of epochs
    "default_dtype": "float32", # Precision for calculations
    "device": "cuda", # Device to use ("cuda" for GPU)
    "seed": 123,
}

# Save parameters to a YAML file
input_mace = mace_configs_dir / "input.yaml"

with open(input_mace, "w") as file:
    yaml.dump(parameters_mace, file, default_flow_style=False)

print(f"Parameters have been saved to {input_mace}")
# Out:
# Parameters have been saved to /content/mace/configs/input.yaml

# %% [markdown]
# ### 3.4. Training MACE <a name="mace-train"></a>

# %% [markdown]
# To train a MACE model, you can use the `run_train.py` script.

# %%
# !python3 ./mace/scripts/run_train.py --config="mace/configs/input.yaml"
# Out:
# /usr/local/lib/python3.10/dist-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# 2025-01-03 10:41:15.875 INFO: ===========VERIFYING SETTINGS===========
# 2025-01-03 10:41:15.875 INFO: MACE version: 0.3.9
# 2025-01-03 10:41:15.898 INFO: CUDA version: 12.1, CUDA device: 0
# 2025-01-03 10:41:15.937 INFO: ===========LOADING INPUT DATA===========
# 2025-01-03 10:41:15.937 INFO: Using heads: ['default']
# 2025-01-03 10:41:15.937 INFO: =============    Processing head default     ===========
# 2025-01-03 10:41:16.158 WARNING: Since ASE version 3.23.0b1, using energy_key 'energy' is no longer safe when communicating between MACE and ASE. We recommend using a different key, rewriting 'energy' to 'REF_energy'. You need to use --energy_key='REF_energy' to specify the chosen key name.
# 2025-01-03 10:41:16.243 WARNING: Since ASE version 3.23.0b1, using forces_key 'forces' is no longer safe when communicating between MACE and ASE. We recommend using a different key, rewriting 'forces' to 'REF_forces'. You need to use --forces_key='REF_forces' to specify the chosen key name.
# 2025-01-03 10:41:16.334 INFO: Training set [500 configs, 500 energy, 40500 forces] loaded from 'BOTNet-datasets/dataset_3BPA/train_mixedT.xyz'
# 2025-01-03 10:41:16.336 INFO: Using random 5% of training set for validation with indices saved in: ./valid_indices_123.txt
# 2025-01-03 10:41:16.336 INFO: Validaton set contains 25 configurations [25 energy, 2025 forces]
# 2025-01-03 10:41:16.336 INFO: Total number of configurations: train=475, valid=25, tests=[],
# 2025-01-03 10:41:16.339 INFO: Atomic Numbers used: [1, 6, 7, 8]
# 2025-01-03 10:41:16.339 INFO: Isolated Atomic Energies (E0s) not in training file, using command line argument
# 2025-01-03 10:41:16.339 INFO: Atomic Energies used (z: eV) for head default: {1: -13.663181292231226, 6: -1029.2809654211628, 7: -1484.1187695035828, 8: -2042.0330099956639}
# 2025-01-03 10:41:16.771 INFO: Computing average number of neighbors
# 2025-01-03 10:41:17.041 INFO: Average number of neighbors: 12.017494201660156
# 2025-01-03 10:41:17.042 INFO: During training the following quantities will be reported: energy, forces
# 2025-01-03 10:41:17.042 INFO: ===========MODEL DETAILS===========
# 2025-01-03 10:41:17.184 INFO: Building model
# 2025-01-03 10:41:17.184 INFO: Message passing with 64 channels and max_L=1 (64x0e+64x1o)
# 2025-01-03 10:41:17.184 INFO: 2 layers, each with correlation order: 3 (body order: 4) and spherical harmonics up to: l=3
# 2025-01-03 10:41:17.184 INFO: 8 radial and 5 basis functions
# 2025-01-03 10:41:17.184 INFO: Radial cutoff: 4.0 A (total receptive field for each atom: 8.0 A)
# 2025-01-03 10:41:17.185 INFO: Distance transform for radial basis functions: None
# 2025-01-03 10:41:17.185 INFO: Hidden irreps: 64x0e+64x1o
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# 2025-01-03 10:41:18.834 INFO: Total number of parameters: 269136
# 2025-01-03 10:41:18.834 INFO:
# 2025-01-03 10:41:18.834 INFO: ===========OPTIMIZER INFORMATION===========
# 2025-01-03 10:41:18.834 INFO: Using ADAM as parameter optimizer
# 2025-01-03 10:41:18.834 INFO: Batch size: 10
# 2025-01-03 10:41:18.834 INFO: Number of gradient updates: 950
# 2025-01-03 10:41:18.834 INFO: Learning rate: 0.01, weight decay: 5e-07
# 2025-01-03 10:41:18.834 INFO: WeightedEnergyForcesLoss(energy_weight=1.000, forces_weight=100.000)
# 2025-01-03 10:41:18.835 INFO: Using gradient clipping with tolerance=10.000
# 2025-01-03 10:41:18.835 INFO:
# 2025-01-03 10:41:18.835 INFO: ===========TRAINING===========
# 2025-01-03 10:41:18.835 INFO: Started training, reporting errors on validation set
# 2025-01-03 10:41:18.835 INFO: Loss metrics on validation set
# 2025-01-03 10:41:22.240 INFO: Initial: head: default, loss=22.08538628, RMSE_E_per_atom= 4957.70 meV, RMSE_F= 1272.96 meV / A
# 2025-01-03 10:41:39.712 INFO: Epoch 0: head: default, loss=4.21828604, RMSE_E_per_atom= 2916.56 meV, RMSE_F=  518.53 meV / A
# 2025-01-03 10:41:44.629 INFO: Epoch 1: head: default, loss=2.27835608, RMSE_E_per_atom= 1937.69 meV, RMSE_F=  388.97 meV / A
# 2025-01-03 10:41:48.383 INFO: Epoch 2: head: default, loss=1.12062871, RMSE_E_per_atom= 1182.98 meV, RMSE_F=  282.53 meV / A
# 2025-01-03 10:41:53.074 INFO: Epoch 3: head: default, loss=0.58474439, RMSE_E_per_atom=  640.34 meV, RMSE_F=  211.11 meV / A
# 2025-01-03 10:41:56.861 INFO: Epoch 4: head: default, loss=0.68823481, RMSE_E_per_atom=  360.09 meV, RMSE_F=  235.46 meV / A
# 2025-01-03 10:42:00.592 INFO: Epoch 5: head: default, loss=0.38321823, RMSE_E_per_atom=  203.80 meV, RMSE_F=  178.15 meV / A
# 2025-01-03 10:42:05.221 INFO: Epoch 6: head: default, loss=0.31581312, RMSE_E_per_atom=  105.33 meV, RMSE_F=  161.56 meV / A
# 2025-01-03 10:42:09.030 INFO: Epoch 7: head: default, loss=0.36070159, RMSE_E_per_atom=  131.99 meV, RMSE_F=  172.71 meV / A
# 2025-01-03 10:42:12.796 INFO: Epoch 8: head: default, loss=0.27383506, RMSE_E_per_atom=   66.18 meV, RMSE_F=  151.58 meV / A
# 2025-01-03 10:42:17.132 INFO: Epoch 9: head: default, loss=0.32645622, RMSE_E_per_atom=   20.42 meV, RMSE_F=  165.61 meV / A
# 2025-01-03 10:42:21.273 INFO: Epoch 10: head: default, loss=0.25643536, RMSE_E_per_atom=   58.49 meV, RMSE_F=  147.47 meV / A
# 2025-01-03 10:42:25.045 INFO: Epoch 11: head: default, loss=0.25907099, RMSE_E_per_atom=  113.41 meV, RMSE_F=  146.85 meV / A
# 2025-01-03 10:42:28.990 INFO: Epoch 12: head: default, loss=0.22136368, RMSE_E_per_atom=   85.18 meV, RMSE_F=  135.95 meV / A
# 2025-01-03 10:42:33.402 INFO: Epoch 13: head: default, loss=0.20226769, RMSE_E_per_atom=    7.82 meV, RMSE_F=  131.07 meV / A
# 2025-01-03 10:42:37.177 INFO: Epoch 14: head: default, loss=0.18774141, RMSE_E_per_atom=   46.55 meV, RMSE_F=  125.22 meV / A
# 2025-01-03 10:42:40.960 INFO: Epoch 15: head: default, loss=0.15374953, RMSE_E_per_atom=   14.20 meV, RMSE_F=  114.08 meV / A
# 2025-01-03 10:42:45.639 INFO: Epoch 16: head: default, loss=0.18132624, RMSE_E_per_atom=   23.93 meV, RMSE_F=  124.22 meV / A
# 2025-01-03 10:42:49.395 INFO: Epoch 17: head: default, loss=0.13194171, RMSE_E_per_atom=   50.13 meV, RMSE_F=  104.97 meV / A
# 2025-01-03 10:42:53.181 INFO: Epoch 18: head: default, loss=0.10985287, RMSE_E_per_atom=   21.01 meV, RMSE_F=   95.41 meV / A
# 2025-01-03 10:42:57.867 INFO: Epoch 19: head: default, loss=0.12763554, RMSE_E_per_atom=   57.81 meV, RMSE_F=  103.67 meV / A
# 2025-01-03 10:42:57.867 INFO: Training complete
# 2025-01-03 10:42:57.867 INFO:
# 2025-01-03 10:42:57.867 INFO: ===========RESULTS===========
# 2025-01-03 10:42:57.867 INFO: Computing metrics for training, validation, and test sets
# 2025-01-03 10:42:57.868 INFO: Loading checkpoint: /content/mace/results/botnet_3bpa_run-123_epoch-18.pt
# /usr/local/lib/python3.10/dist-packages/mace/tools/checkpoint.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(f=checkpoint_info.path, map_location=device),
# 2025-01-03 10:42:57.902 INFO: Loaded Stage one model from epoch 18 for evaluation
# 2025-01-03 10:42:57.903 INFO: Evaluating train_default ...
# 2025-01-03 10:42:59.605 INFO: Evaluating valid_default ...
# 2025-01-03 10:42:59.715 INFO: Error-table on TRAIN and VALID:
# +---------------+---------------------+------------------+-------------------+
# |  config_type  | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +---------------+---------------------+------------------+-------------------+
# | train_default |           20.8      |         94.6     |          6.63     |
# | valid_default |           21.0      |         95.4     |          7.50     |
# +---------------+---------------------+------------------+-------------------+
# 2025-01-03 10:42:59.715 INFO: Saving model to /content/mace/results/botnet_3bpa_run-123.model
# 2025-01-03 10:42:59.914 INFO: Compiling model, saving metadata to /content/mace/results/botnet_3bpa_compiled.model
# 2025-01-03 10:43:00.785 INFO: Done

# %% [markdown]
# **Extra:** Try running the model with different hyperparameters.

# %%
# Check the output files
mace_train_dir = Path(parameters_mace["model_dir"])
for file in mace_train_dir.rglob("*"):
    print(file)
# Out:
# /content/mace/results/botnet_3bpa_run-123_train.txt
# /content/mace/results/botnet_3bpa_run-123_debug.log
# /content/mace/results/botnet_3bpa_compiled.model
# /content/mace/results/botnet_3bpa_run-123.model
# /content/mace/results/botnet_3bpa_run-123.log
# /content/mace/results/botnet_3bpa_run-123_epoch-18.pt
# /content/mace/results/botnet_3bpa.model

# %% [markdown]
# Check the file saved as `..._train.txt` for information of about training.

# %%
mace_train_txt = mace_train_dir / f"{parameters_mace['name']}_run-{parameters_mace['seed']}_train.txt"

# Parsing the file
eval_data = {}
opt_data = {}

with open(mace_train_txt, 'r') as file:
    lines = file.readlines()

    for line in lines:
        try:
            record = json.loads(line)

            if record["mode"] == "eval":
                # Extract the epoch
                epoch = record.get("epoch", None)
                epoch_key = epoch if epoch is not None else None

                # Initialize a sub-dictionary for this epoch if not already present
                if epoch_key not in eval_data:
                    eval_data[epoch_key] = {}

                # Add all other keys (except 'mode' and 'epoch') to the sub-dictionary
                for key, value in record.items():
                    if key not in ["mode", "epoch"]:
                        eval_data[epoch_key][key] = value

            elif record["mode"] == "opt":
                # Extract the epoch
                epoch = record.get("epoch", None)
                epoch_key = epoch if epoch is not None else None

                # Initialize a sub-dictionary for this epoch if not already present
                if epoch_key not in opt_data:
                    opt_data[epoch_key] = {}

                # Initialize lists for all keys including 'epoch' if not present
                for key in record:
                    if key not in ["mode", "epoch"]: # Removed "epoch" to initialize it
                        if key not in opt_data[epoch_key]:  # This line is crucial
                            opt_data[epoch_key][key] = []

                # Append values to the lists
                for key, value in record.items():
                    if key not in ["mode", "epoch"]:
                        opt_data[epoch_key][key].append(value)

        except json.JSONDecodeError:
            continue

# %%
opt_data
# Out:
# {0: {'loss': [221.8868408203125,
#    248.12734985351562,
#    258.8162841796875,
#    176.9788360595703,
#    238.8463592529297,
#    167.29005432128906,
#    206.89266967773438,
#    168.9969940185547,
#    172.562255859375,
#    111.81385803222656,
#    133.919921875,
#    137.19979858398438,
#    148.6923370361328,
#    179.6634979248047,
#    175.95472717285156,
#    169.26318359375,
#    130.85963439941406,
#    112.91535186767578,
#    82.46636962890625,
#    105.2048110961914,
#    89.32984924316406,
#    68.56367492675781,
#    88.38951873779297,
#    74.75605773925781,
#    62.40447998046875,
#    65.35279846191406,
#    66.76416015625,
#    71.32389831542969,
#    63.00005340576172,
#    57.487945556640625,
#    51.197662353515625,
#    51.28580093383789,
#    55.330894470214844,
#    50.7432975769043,
#    44.279075622558594,
#    53.5224609375,
#    47.193603515625,
#    36.45761489868164,
#    52.45545959472656,
#    44.56434631347656,
#    39.185516357421875,
#    50.24712371826172,
#    49.24897766113281,
#    52.42361068725586,
#    50.29534149169922,
#    54.73234176635742,
#    37.58039093017578],
#   'time': [2.3975303173065186,
#    2.7794415950775146,
#    3.2289717197418213,
#    2.231978416442871,
#    2.3486170768737793,
#    0.09773564338684082,
#    0.08139824867248535,
#    0.07513785362243652,
#    0.07654833793640137,
#    0.07402586936950684,
#    0.07522368431091309,
#    0.0749659538269043,
#    0.07492852210998535,
#    0.07343125343322754,
#    0.07320141792297363,
#    0.07301926612854004,
#    0.07298874855041504,
#    0.11271429061889648,
#    0.10202479362487793,
#    0.1068873405456543,
#    0.09471654891967773,
#    0.09448575973510742,
#    0.10117173194885254,
#    0.09674501419067383,
#    0.0924675464630127,
#    0.0915060043334961,
#    0.08985757827758789,
#    0.0911264419555664,
#    0.10553264617919922,
#    0.10045409202575684,
#    0.11444592475891113,
#    0.10730576515197754,
#    0.11853265762329102,
#    0.10536670684814453,
#    0.10442399978637695,
#    0.10129165649414062,
#    0.1019282341003418,
#    0.1037290096282959,
#    0.10494303703308105,
#    0.10618877410888672,
#    0.10445737838745117,
#    0.10685491561889648,
#    0.11458206176757812,
#    0.11374211311340332,
#    0.08318138122558594,
#    0.07255959510803223,
#    0.07182955741882324]},
#  1: {'loss': [31.415470123291016,
#    38.00746536254883,
#    28.89694595336914,
#    35.17353820800781,
#    38.29800796508789,
#    35.371795654296875,
#    37.83069610595703,
#    38.13753128051758,
#    39.41914367675781,
#    29.44749641418457,
#    36.53424072265625,
#    28.44049644470215,
#    35.20123291015625,
#    35.58474349975586,
#    32.74330139160156,
#    35.645408630371094,
#    29.23407745361328,
#    34.23607635498047,
#    28.46525001525879,
#    24.377758026123047,
#    22.128116607666016,
#    27.59598731994629,
#    25.381935119628906,
#    30.078723907470703,
#    33.179542541503906,
#    34.62340545654297,
#    24.817522048950195,
#    29.83843994140625,
#    30.75471305847168,
#    26.905258178710938,
#    24.694894790649414,
#    32.080162048339844,
#    27.052919387817383,
#    23.440109252929688,
#    27.477380752563477,
#    27.349475860595703,
#    23.672500610351562,
#    22.522560119628906,
#    23.24030113220215,
#    23.7949275970459,
#    28.256267547607422,
#    22.37773895263672,
#    11.889114379882812,
#    18.31439971923828,
#    21.070323944091797,
#    18.824506759643555,
#    15.205669403076172],
#   'time': [0.07366204261779785,
#    0.07527804374694824,
#    0.07504558563232422,
#    0.08178019523620605,
#    0.07404661178588867,
#    0.07406926155090332,
#    0.07431221008300781,
#    0.07253837585449219,
#    0.07516646385192871,
#    0.07241940498352051,
#    0.07378649711608887,
#    0.07352614402770996,
#    0.0732719898223877,
#    0.07486844062805176,
#    0.07187175750732422,
#    0.07270312309265137,
#    0.08575963973999023,
#    0.07579231262207031,
#    0.0748281478881836,
#    0.07314467430114746,
#    0.07354044914245605,
#    0.07268548011779785,
#    0.0727393627166748,
#    0.07226943969726562,
#    0.07324481010437012,
#    0.07210469245910645,
#    0.07265472412109375,
#    0.07207298278808594,
#    0.07345390319824219,
#    0.08199810981750488,
#    0.07488441467285156,
#    0.07331275939941406,
#    0.07367348670959473,
#    0.07450485229492188,
#    0.07371902465820312,
#    0.07447123527526855,
#    0.07267212867736816,
#    0.0734703540802002,
#    0.0737142562866211,
#    0.07224893569946289,
#    0.07310199737548828,
#    0.07228469848632812,
#    0.08358359336853027,
#    0.07343935966491699,
#    0.07291436195373535,
#    0.0718388557434082,
#    0.07211804389953613]},
#  2: {'loss': [13.886716842651367,
#    19.316625595092773,
#    17.759002685546875,
#    17.916725158691406,
#    11.878433227539062,
#    17.47646141052246,
#    17.693199157714844,
#    13.88251781463623,
#    18.165874481201172,
#    14.509062767028809,
#    15.643754005432129,
#    20.621078491210938,
#    17.504735946655273,
#    17.922138214111328,
#    15.818389892578125,
#    14.360055923461914,
#    15.184659957885742,
#    23.50912857055664,
#    22.0102596282959,
#    15.129374504089355,
#    12.949569702148438,
#    14.294136047363281,
#    14.920851707458496,
#    14.306009292602539,
#    11.014816284179688,
#    9.619413375854492,
#    10.166053771972656,
#    9.0263671875,
#    12.961406707763672,
#    14.399837493896484,
#    15.775919914245605,
#    10.254237174987793,
#    16.03489112854004,
#    15.680388450622559,
#    14.894556045532227,
#    15.472965240478516,
#    11.036629676818848,
#    10.171213150024414,
#    15.474746704101562,
#    15.957868576049805,
#    11.96155834197998,
#    10.797408103942871,
#    11.263518333435059,
#    13.143606185913086,
#    14.925289154052734,
#    11.644575119018555,
#    12.347695350646973],
#   'time': [0.0726933479309082,
#    0.07252311706542969,
#    0.07431483268737793,
#    0.07284212112426758,
#    0.07161068916320801,
#    0.07199645042419434,
#    0.08368587493896484,
#    0.0717477798461914,
#    0.0733339786529541,
#    0.07167911529541016,
#    0.07165646553039551,
#    0.07396936416625977,
#    0.0745391845703125,
#    0.07293200492858887,
#    0.07188177108764648,
#    0.07238531112670898,
#    0.07183647155761719,
#    0.07166814804077148,
#    0.07170987129211426,
#    0.08426475524902344,
#    0.0720376968383789,
#    0.07146024703979492,
#    0.07333564758300781,
#    0.07300114631652832,
#    0.07320761680603027,
#    0.0738382339477539,
#    0.07241249084472656,
#    0.07155013084411621,
#    0.07186651229858398,
#    0.07226991653442383,
#    0.07125735282897949,
#    0.07129836082458496,
#    0.08210968971252441,
#    0.07168841361999512,
#    0.07161593437194824,
#    0.07247447967529297,
#    0.07190465927124023,
#    0.07391881942749023,
#    0.07342076301574707,
#    0.07510948181152344,
#    0.07249593734741211,
#    0.07187652587890625,
#    0.07157588005065918,
#    0.07170867919921875,
#    0.0719001293182373,
#    0.07369804382324219,
#    0.07562661170959473]},
#  3: {'loss': [9.653928756713867,
#    9.802490234375,
#    11.268115997314453,
#    10.64939022064209,
#    9.796093940734863,
#    8.397995948791504,
#    8.291147232055664,
#    10.72248363494873,
#    7.900363922119141,
#    12.818279266357422,
#    8.785163879394531,
#    8.881010055541992,
#    10.862974166870117,
#    9.35179328918457,
#    9.582232475280762,
#    11.369125366210938,
#    7.8938703536987305,
#    7.245240211486816,
#    9.851458549499512,
#    8.941856384277344,
#    5.158883571624756,
#    9.557720184326172,
#    7.418456554412842,
#    8.248442649841309,
#    8.938039779663086,
#    9.33454704284668,
#    7.451645851135254,
#    7.804169654846191,
#    7.608323097229004,
#    9.257863998413086,
#    7.55689811706543,
#    7.364520072937012,
#    6.591592788696289,
#    8.519901275634766,
#    6.883219242095947,
#    6.738339900970459,
#    6.424337387084961,
#    9.492904663085938,
#    7.192901611328125,
#    7.436514377593994,
#    5.5056843757629395,
#    6.413204669952393,
#    6.665851593017578,
#    6.148353576660156,
#    6.669648170471191,
#    6.563190937042236,
#    6.702243328094482],
#   'time': [0.07258462905883789,
#    0.07119941711425781,
#    0.07246255874633789,
#    0.08214235305786133,
#    0.07920479774475098,
#    0.07692337036132812,
#    0.07330489158630371,
#    0.07278800010681152,
#    0.07473134994506836,
#    0.0753471851348877,
#    0.11455082893371582,
#    0.10416245460510254,
#    0.11091470718383789,
#    0.09415674209594727,
#    0.09344863891601562,
#    0.09507989883422852,
#    0.09769034385681152,
#    0.09085440635681152,
#    0.09314346313476562,
#    0.0903635025024414,
#    0.10482358932495117,
#    0.09986400604248047,
#    0.10443806648254395,
#    0.10378789901733398,
#    0.10445213317871094,
#    0.11336326599121094,
#    0.11327338218688965,
#    0.10302042961120605,
#    0.10077500343322754,
#    0.11706066131591797,
#    0.1040503978729248,
#    0.10219430923461914,
#    0.10551309585571289,
#    0.10052633285522461,
#    0.10063433647155762,
#    0.10289311408996582,
#    0.10681653022766113,
#    0.11291170120239258,
#    0.0749964714050293,
#    0.08137369155883789,
#    0.07217955589294434,
#    0.07460784912109375,
#    0.0727853775024414,
#    0.07151150703430176,
#    0.07282209396362305,
#    0.07245945930480957,
#    0.07218718528747559]},
#  4: {'loss': [3.8415944576263428,
#    6.818504333496094,
#    9.306796073913574,
#    5.350167274475098,
#    5.713954925537109,
#    7.9671735763549805,
#    5.845462322235107,
#    8.696866989135742,
#    6.671593189239502,
#    6.1548991203308105,
#    4.563680171966553,
#    7.264336585998535,
#    7.393793106079102,
#    6.428873538970947,
#    4.169750690460205,
#    5.860147476196289,
#    6.688199996948242,
#    7.670797348022461,
#    6.81935977935791,
#    3.499361515045166,
#    5.402700901031494,
#    2.808718204498291,
#    3.6715826988220215,
#    4.890539646148682,
#    5.648891448974609,
#    4.067684173583984,
#    5.28344202041626,
#    4.412785053253174,
#    5.383741855621338,
#    6.813285827636719,
#    9.257966995239258,
#    4.4297943115234375,
#    8.798995018005371,
#    12.264649391174316,
#    5.718111515045166,
#    8.781224250793457,
#    6.871848106384277,
#    6.286023139953613,
#    6.199778079986572,
#    6.136379241943359,
#    4.016658782958984,
#    3.504443883895874,
#    5.681957244873047,
#    5.3544697761535645,
#    6.465588569641113,
#    4.61251163482666,
#    5.130640029907227],
#   'time': [0.07467842102050781,
#    0.07187318801879883,
#    0.07297468185424805,
#    0.0751643180847168,
#    0.0812535285949707,
#    0.07302331924438477,
#    0.07246541976928711,
#    0.07308530807495117,
#    0.0717325210571289,
#    0.07437443733215332,
#    0.07204294204711914,
#    0.07277703285217285,
#    0.07401704788208008,
#    0.07396054267883301,
#    0.0718691349029541,
#    0.07109522819519043,
#    0.07234477996826172,
#    0.0806434154510498,
#    0.07254767417907715,
#    0.07723641395568848,
#    0.07303357124328613,
#    0.07172608375549316,
#    0.07156085968017578,
#    0.07186079025268555,
#    0.07222461700439453,
#    0.07187986373901367,
#    0.07377743721008301,
#    0.07185173034667969,
#    0.07199668884277344,
#    0.07303953170776367,
#    0.07974791526794434,
#    0.07222294807434082,
#    0.07271599769592285,
#    0.07280087471008301,
#    0.0722646713256836,
#    0.07199907302856445,
#    0.07227659225463867,
#    0.07210636138916016,
#    0.07152748107910156,
#    0.07309675216674805,
#    0.0719306468963623,
#    0.07168197631835938,
#    0.07227516174316406,
#    0.07851934432983398,
#    0.07984066009521484,
#    0.0725259780883789,
#    0.08451652526855469]},
#  5: {'loss': [5.522488594055176,
#    8.271523475646973,
#    8.408249855041504,
#    3.7727227210998535,
#    4.012009143829346,
#    6.000770092010498,
#    6.161889553070068,
#    6.648412227630615,
#    7.162010669708252,
#    7.4879326820373535,
#    5.3457512855529785,
#    6.94061803817749,
#    5.318733215332031,
#    5.971813201904297,
#    4.518979549407959,
#    3.4756596088409424,
#    5.445117473602295,
#    4.865920066833496,
#    5.155652046203613,
#    5.615889549255371,
#    2.8929054737091064,
#    8.221171379089355,
#    5.183517932891846,
#    3.418614149093628,
#    3.5220675468444824,
#    4.814706802368164,
#    5.433565139770508,
#    4.177745819091797,
#    3.75254225730896,
#    4.186322212219238,
#    4.078356742858887,
#    3.96529221534729,
#    4.179530143737793,
#    4.2726006507873535,
#    4.043817520141602,
#    4.544313430786133,
#    3.734588623046875,
#    4.012912273406982,
#    4.054052352905273,
#    4.137370586395264,
#    4.792502403259277,
#    3.3950860500335693,
#    2.7891037464141846,
#    3.6463539600372314,
#    3.3667807579040527,
#    3.0000035762786865,
#    4.136545658111572],
#   'time': [0.0717008113861084,
#    0.07157588005065918,
#    0.0721898078918457,
#    0.07386136054992676,
#    0.0722041130065918,
#    0.07175970077514648,
#    0.0722508430480957,
#    0.07176995277404785,
#    0.07971072196960449,
#    0.07418084144592285,
#    0.07617878913879395,
#    0.07159090042114258,
#    0.07193636894226074,
#    0.07168936729431152,
#    0.07268667221069336,
#    0.0714409351348877,
#    0.07363533973693848,
#    0.07276439666748047,
#    0.0720827579498291,
#    0.07232236862182617,
#    0.07226371765136719,
#    0.07245683670043945,
#    0.08173251152038574,
#    0.07323694229125977,
#    0.07271862030029297,
#    0.07172369956970215,
#    0.07149338722229004,
#    0.07204961776733398,
#    0.07253003120422363,
#    0.07348322868347168,
#    0.0727529525756836,
#    0.07222127914428711,
#    0.07172918319702148,
#    0.07333207130432129,
#    0.07197165489196777,
#    0.08400177955627441,
#    0.0736851692199707,
#    0.07235002517700195,
#    0.07192420959472656,
#    0.0708150863647461,
#    0.07205867767333984,
#    0.07182645797729492,
#    0.0741732120513916,
#    0.0726633071899414,
#    0.07176613807678223,
#    0.07333827018737793,
#    0.07346272468566895]},
#  6: {'loss': [3.0507941246032715,
#    3.950186014175415,
#    4.084238529205322,
#    2.879009962081909,
#    4.405394077301025,
#    2.550105333328247,
#    4.512016296386719,
#    4.3502516746521,
#    3.719402551651001,
#    4.460119247436523,
#    3.9143025875091553,
#    4.036036491394043,
#    3.991013288497925,
#    4.028621196746826,
#    3.396259307861328,
#    4.374800205230713,
#    2.5465586185455322,
#    2.5950663089752197,
#    4.035308361053467,
#    3.5907206535339355,
#    4.809746265411377,
#    4.564547538757324,
#    3.01875376701355,
#    3.0202012062072754,
#    3.626695156097412,
#    4.192470073699951,
#    3.358293294906616,
#    3.069908380508423,
#    3.028291940689087,
#    2.8295397758483887,
#    2.336418628692627,
#    2.899068593978882,
#    3.435500144958496,
#    2.464768886566162,
#    3.9792909622192383,
#    3.6157374382019043,
#    4.650240421295166,
#    2.200709104537964,
#    3.966715097427368,
#    2.388178825378418,
#    2.1819264888763428,
#    3.6843295097351074,
#    3.2422730922698975,
#    3.518848180770874,
#    2.965017557144165,
#    3.256442070007324,
#    2.568171977996826],
#   'time': [0.07507538795471191,
#    0.07196640968322754,
#    0.07408905029296875,
#    0.07186055183410645,
#    0.07695436477661133,
#    0.0782172679901123,
#    0.07389616966247559,
#    0.07393765449523926,
#    0.07221436500549316,
#    0.07204103469848633,
#    0.0726773738861084,
#    0.07218313217163086,
#    0.07652497291564941,
#    0.07541799545288086,
#    0.07205748558044434,
#    0.07219815254211426,
#    0.0731511116027832,
#    0.07160472869873047,
#    0.0717158317565918,
#    0.0730440616607666,
#    0.07332468032836914,
#    0.10438752174377441,
#    0.1029200553894043,
#    0.11217665672302246,
#    0.10875868797302246,
#    0.09289240837097168,
#    0.09164714813232422,
#    0.09460854530334473,
#    0.08749651908874512,
#    0.09020280838012695,
#    0.08700156211853027,
#    0.08730840682983398,
#    0.09580421447753906,
#    0.10646462440490723,
#    0.0981588363647461,
#    0.11723875999450684,
#    0.10121917724609375,
#    0.10822343826293945,
#    0.10313677787780762,
#    0.10463833808898926,
#    0.10045599937438965,
#    0.10280895233154297,
#    0.10505390167236328,
#    0.10361337661743164,
#    0.11705708503723145,
#    0.10437321662902832,
#    0.10170459747314453]},
#  7: {'loss': [3.033351421356201,
#    3.291313886642456,
#    3.2192211151123047,
#    3.731153726577759,
#    2.5723459720611572,
#    4.545776844024658,
#    3.753560781478882,
#    3.174295425415039,
#    3.4101860523223877,
#    2.0457262992858887,
#    1.7068605422973633,
#    3.7211527824401855,
#    4.629818916320801,
#    2.6159791946411133,
#    2.6023361682891846,
#    3.9934396743774414,
#    4.303828239440918,
#    2.2751898765563965,
#    1.9048829078674316,
#    3.5285041332244873,
#    2.5863394737243652,
#    2.4447717666625977,
#    2.5976150035858154,
#    3.308372735977173,
#    2.39870548248291,
#    4.278141498565674,
#    3.308967351913452,
#    2.0542843341827393,
#    2.6537139415740967,
#    3.5257463455200195,
#    3.906095504760742,
#    2.8918557167053223,
#    2.8156728744506836,
#    3.757702112197876,
#    3.1667819023132324,
#    2.959421396255493,
#    2.7908318042755127,
#    2.745469808578491,
#    2.9145121574401855,
#    3.596855401992798,
#    4.209554672241211,
#    3.297884941101074,
#    3.588409423828125,
#    2.855902910232544,
#    3.0823450088500977,
#    5.099736213684082,
#    4.989660739898682],
#   'time': [0.08143448829650879,
#    0.07336306571960449,
#    0.07291173934936523,
#    0.07520151138305664,
#    0.0739433765411377,
#    0.07303714752197266,
#    0.07252335548400879,
#    0.08025050163269043,
#    0.07255697250366211,
#    0.07186532020568848,
#    0.07264208793640137,
#    0.07274007797241211,
#    0.07394599914550781,
#    0.07184219360351562,
#    0.07247304916381836,
#    0.07410645484924316,
#    0.0731668472290039,
#    0.07297539710998535,
#    0.0735619068145752,
#    0.07218074798583984,
#    0.08017587661743164,
#    0.07438540458679199,
#    0.07210135459899902,
#    0.07181215286254883,
#    0.07253813743591309,
#    0.07423925399780273,
#    0.0729529857635498,
#    0.07249951362609863,
#    0.07433152198791504,
#    0.07372570037841797,
#    0.07508468627929688,
#    0.0722663402557373,
#    0.07391119003295898,
#    0.07256054878234863,
#    0.07699728012084961,
#    0.07264924049377441,
#    0.0731813907623291,
#    0.07273316383361816,
#    0.07279586791992188,
#    0.07271361351013184,
#    0.07245087623596191,
#    0.0735783576965332,
#    0.07367229461669922,
#    0.07378196716308594,
#    0.0723581314086914,
#    0.07236170768737793,
#    0.07238268852233887]},
#  8: {'loss': [3.498164415359497,
#    4.794846534729004,
#    2.445044994354248,
#    2.8062896728515625,
#    3.14064884185791,
#    4.077744960784912,
#    3.676281213760376,
#    3.787998676300049,
#    4.529043197631836,
#    3.782719373703003,
#    2.411712169647217,
#    2.3167223930358887,
#    4.13405179977417,
#    4.9230570793151855,
#    4.762621879577637,
#    3.2673635482788086,
#    2.7238457202911377,
#    2.4948067665100098,
#    3.1000285148620605,
#    2.692845106124878,
#    3.4433066844940186,
#    3.8396825790405273,
#    2.265655994415283,
#    1.834633469581604,
#    3.1051158905029297,
#    2.772834062576294,
#    2.4073216915130615,
#    3.6420087814331055,
#    2.675814390182495,
#    2.0438876152038574,
#    3.442568063735962,
#    2.940779447555542,
#    2.3181967735290527,
#    2.536311626434326,
#    3.2954633235931396,
#    3.1848537921905518,
#    4.080270767211914,
#    3.6212408542633057,
#    1.6213183403015137,
#    2.1540799140930176,
#    2.4588968753814697,
#    2.1656949520111084,
#    3.839214324951172,
#    4.241684436798096,
#    2.954834461212158,
#    3.4171018600463867,
#    3.3618662357330322],
#   'time': [0.07218408584594727,
#    0.07371306419372559,
#    0.07333755493164062,
#    0.07268404960632324,
#    0.0730431079864502,
#    0.07271194458007812,
#    0.07330012321472168,
#    0.07780218124389648,
#    0.07383418083190918,
#    0.07245826721191406,
#    0.07270073890686035,
#    0.07256197929382324,
#    0.0785224437713623,
#    0.07263636589050293,
#    0.07305550575256348,
#    0.0741569995880127,
#    0.07217025756835938,
#    0.07224535942077637,
#    0.0723564624786377,
#    0.07367205619812012,
#    0.07462382316589355,
#    0.07312250137329102,
#    0.07350802421569824,
#    0.0727393627166748,
#    0.07209515571594238,
#    0.08292841911315918,
#    0.07302117347717285,
#    0.07232260704040527,
#    0.07404327392578125,
#    0.07193803787231445,
#    0.0726006031036377,
#    0.07249140739440918,
#    0.07386469841003418,
#    0.07573795318603516,
#    0.07501792907714844,
#    0.07410717010498047,
#    0.07344508171081543,
#    0.07301020622253418,
#    0.08233189582824707,
#    0.07264065742492676,
#    0.07365679740905762,
#    0.07483768463134766,
#    0.07293438911437988,
#    0.07265734672546387,
#    0.07309913635253906,
#    0.07467007637023926,
#    0.07476544380187988]},
#  9: {'loss': [1.9557160139083862,
#    3.5767011642456055,
#    2.1831159591674805,
#    2.1800169944763184,
#    2.7810707092285156,
#    2.370988368988037,
#    1.9905226230621338,
#    3.561387538909912,
#    1.9221642017364502,
#    3.8837032318115234,
#    2.5946953296661377,
#    2.2174806594848633,
#    1.8719394207000732,
#    2.9246537685394287,
#    1.4682425260543823,
#    3.2535691261291504,
#    4.732602119445801,
#    1.778239369392395,
#    3.093498706817627,
#    3.160856246948242,
#    1.4187804460525513,
#    2.8545479774475098,
#    3.268738269805908,
#    2.7854983806610107,
#    2.6870312690734863,
#    3.467371702194214,
#    2.2523720264434814,
#    2.743114948272705,
#    3.612506866455078,
#    1.818284273147583,
#    2.4907898902893066,
#    3.885998249053955,
#    2.1255242824554443,
#    2.329397678375244,
#    2.461949348449707,
#    1.422438383102417,
#    1.9122843742370605,
#    1.806933879852295,
#    2.99448823928833,
#    2.224552631378174,
#    2.8279941082000732,
#    1.6462821960449219,
#    1.937639832496643,
#    1.7609330415725708,
#    3.0131263732910156,
#    3.461899518966675,
#    1.6469709873199463],
#   'time': [0.07311105728149414,
#    0.07336044311523438,
#    0.08155274391174316,
#    0.07257556915283203,
#    0.07376408576965332,
#    0.07441568374633789,
#    0.0736396312713623,
#    0.07230734825134277,
#    0.07275581359863281,
#    0.0733788013458252,
#    0.07363104820251465,
#    0.07274413108825684,
#    0.07216072082519531,
#    0.07242465019226074,
#    0.07284736633300781,
#    0.07258868217468262,
#    0.07794475555419922,
#    0.07326316833496094,
#    0.07399606704711914,
#    0.07333874702453613,
#    0.07280182838439941,
#    0.07263541221618652,
#    0.07375812530517578,
#    0.07378649711608887,
#    0.07239675521850586,
#    0.07228970527648926,
#    0.07274174690246582,
#    0.07281184196472168,
#    0.0724642276763916,
#    0.0821077823638916,
#    0.07265901565551758,
#    0.11145758628845215,
#    0.12408900260925293,
#    0.12272810935974121,
#    0.09929084777832031,
#    0.09216785430908203,
#    0.09183835983276367,
#    0.09172940254211426,
#    0.09409666061401367,
#    0.10091853141784668,
#    0.0911870002746582,
#    0.08992981910705566,
#    0.0966804027557373,
#    0.12172555923461914,
#    0.0944364070892334,
#    0.1100761890411377,
#    0.10248160362243652]},
#  10: {'loss': [2.656587839126587,
#    2.989722967147827,
#    1.7530063390731812,
#    2.332825183868408,
#    1.8900609016418457,
#    2.4166455268859863,
#    4.112545013427734,
#    1.8466755151748657,
#    1.9463038444519043,
#    2.7346575260162354,
#    3.412421226501465,
#    2.548222541809082,
#    3.629836320877075,
#    1.9607027769088745,
#    1.650926947593689,
#    2.187366247177124,
#    2.790902853012085,
#    2.2465929985046387,
#    2.787269353866577,
#    2.471130132675171,
#    2.577148199081421,
#    3.7900819778442383,
#    1.672042965888977,
#    1.9799418449401855,
#    2.1142020225524902,
#    2.6554853916168213,
#    1.9686079025268555,
#    1.9248055219650269,
#    2.3516430854797363,
#    1.2201144695281982,
#    2.1436808109283447,
#    2.2447173595428467,
#    2.469742774963379,
#    2.6676578521728516,
#    2.5730206966400146,
#    2.2324836254119873,
#    2.6630406379699707,
#    1.4235820770263672,
#    1.9557136297225952,
#    1.5090303421020508,
#    2.274648427963257,
#    1.7226011753082275,
#    1.9353601932525635,
#    1.4213531017303467,
#    2.6094632148742676,
#    1.6323082447052002,
#    2.615316867828369],
#   'time': [0.11845707893371582,
#    0.10790491104125977,
#    0.10488605499267578,
#    0.10448312759399414,
#    0.1085360050201416,
#    0.10173487663269043,
#    0.10223627090454102,
#    0.1011497974395752,
#    0.10193157196044922,
#    0.10685229301452637,
#    0.11594200134277344,
#    0.08161497116088867,
#    0.07276678085327148,
#    0.07269144058227539,
#    0.07328939437866211,
#    0.0714256763458252,
#    0.07271671295166016,
#    0.07172799110412598,
#    0.0723421573638916,
#    0.07215523719787598,
#    0.07311177253723145,
#    0.07262635231018066,
#    0.08217787742614746,
#    0.07256960868835449,
#    0.07249879837036133,
#    0.07277870178222656,
#    0.07200217247009277,
#    0.07332658767700195,
#    0.07230710983276367,
#    0.07220673561096191,
#    0.07217597961425781,
#    0.07257080078125,
#    0.07217741012573242,
#    0.07292962074279785,
#    0.07182431221008301,
#    0.0793921947479248,
#    0.07242941856384277,
#    0.07202482223510742,
#    0.07228589057922363,
#    0.07486343383789062,
#    0.08191418647766113,
#    0.07756471633911133,
#    0.07263517379760742,
#    0.07225966453552246,
#    0.07183218002319336,
#    0.07187461853027344,
#    0.07296609878540039]},
#  11: {'loss': [2.239027261734009,
#    1.8468893766403198,
#    1.3962196111679077,
#    1.3541264533996582,
#    1.5805727243423462,
#    1.1733287572860718,
#    1.6428923606872559,
#    2.0466408729553223,
#    1.2653398513793945,
#    2.403327703475952,
#    1.5453706979751587,
#    2.949559211730957,
#    2.7719788551330566,
#    3.016850471496582,
#    2.44429087638855,
#    2.1781201362609863,
#    2.1478240489959717,
#    1.1112489700317383,
#    2.902294635772705,
#    2.5086212158203125,
#    2.0495710372924805,
#    2.0417397022247314,
#    2.52303147315979,
#    1.9071857929229736,
#    3.094632387161255,
#    3.4474380016326904,
#    1.7974960803985596,
#    1.8947948217391968,
#    2.277191162109375,
#    2.420851230621338,
#    2.2535359859466553,
#    2.5360875129699707,
#    2.5337467193603516,
#    2.3408913612365723,
#    1.872442603111267,
#    1.511528491973877,
#    1.9178026914596558,
#    1.8370838165283203,
#    1.8720402717590332,
#    2.195655345916748,
#    1.5799182653427124,
#    1.964991569519043,
#    3.0148777961730957,
#    2.5315799713134766,
#    1.7163004875183105,
#    2.0309348106384277,
#    1.8064990043640137],
#   'time': [0.08418059349060059,
#    0.07215642929077148,
#    0.07352614402770996,
#    0.07284307479858398,
#    0.07391834259033203,
#    0.07216763496398926,
#    0.07218718528747559,
#    0.0722808837890625,
#    0.07280588150024414,
#    0.07214498519897461,
#    0.07179021835327148,
#    0.07219362258911133,
#    0.07237863540649414,
#    0.07991814613342285,
#    0.07238435745239258,
#    0.07238030433654785,
#    0.07208490371704102,
#    0.07340264320373535,
#    0.0731973648071289,
#    0.07225728034973145,
#    0.07205772399902344,
#    0.0729975700378418,
#    0.07332777976989746,
#    0.07320570945739746,
#    0.07298779487609863,
#    0.07245373725891113,
#    0.07998204231262207,
#    0.07254767417907715,
#    0.07213163375854492,
#    0.07291531562805176,
#    0.07475495338439941,
#    0.07245182991027832,
#    0.07259464263916016,
#    0.07271409034729004,
#    0.0721743106842041,
#    0.07384514808654785,
#    0.07478928565979004,
#    0.07265996932983398,
#    0.0717000961303711,
#    0.07219910621643066,
#    0.07867264747619629,
#    0.07281184196472168,
#    0.07277369499206543,
#    0.07395601272583008,
#    0.07728338241577148,
#    0.07295870780944824,
#    0.07309269905090332]},
#  12: {'loss': [2.579470157623291,
#    1.4597740173339844,
#    1.3940485715866089,
#    1.998000144958496,
#    1.800994634628296,
#    3.011373281478882,
#    2.48321795463562,
#    1.1994985342025757,
#    1.9252612590789795,
#    1.6098705530166626,
#    1.7103303670883179,
#    2.1011366844177246,
#    1.5712909698486328,
#    2.401510238647461,
#    2.0207059383392334,
#    2.0226950645446777,
#    2.091214418411255,
#    1.5087026357650757,
#    1.2325359582901,
#    1.9770206212997437,
#    1.7965071201324463,
#    1.5867774486541748,
#    1.1865723133087158,
#    2.847271680831909,
#    2.5367157459259033,
#    1.2846037149429321,
#    1.3478726148605347,
#    1.824210286140442,
#    2.284263849258423,
#    1.7871661186218262,
#    1.5233280658721924,
#    1.7210460901260376,
#    1.5793935060501099,
#    2.1940112113952637,
#    2.3185818195343018,
#    1.5759527683258057,
#    1.3044064044952393,
#    2.107710361480713,
#    1.7442467212677002,
#    1.3318060636520386,
#    1.8594608306884766,
#    2.0494306087493896,
#    1.8625792264938354,
#    2.0848312377929688,
#    1.841779112815857,
#    1.2534444332122803,
#    1.491683840751648],
#   'time': [0.07204008102416992,
#    0.07251882553100586,
#    0.07217073440551758,
#    0.07471275329589844,
#    0.07505154609680176,
#    0.07356739044189453,
#    0.07309222221374512,
#    0.07251405715942383,
#    0.07359933853149414,
#    0.07162189483642578,
#    0.07292008399963379,
#    0.07279849052429199,
#    0.0721745491027832,
#    0.07285284996032715,
#    0.07313823699951172,
#    0.07221698760986328,
#    0.07299447059631348,
#    0.0728156566619873,
#    0.08130812644958496,
#    0.07281231880187988,
#    0.07280397415161133,
#    0.07234811782836914,
#    0.0726156234741211,
#    0.09980654716491699,
#    0.07436609268188477,
#    0.07264852523803711,
#    0.07298684120178223,
#    0.07219076156616211,
#    0.07250523567199707,
#    0.07508301734924316,
#    0.07167696952819824,
#    0.07933235168457031,
#    0.07284665107727051,
#    0.07458901405334473,
#    0.07277536392211914,
#    0.07194256782531738,
#    0.07335495948791504,
#    0.07397747039794922,
#    0.07393002510070801,
#    0.07382941246032715,
#    0.07280206680297852,
#    0.07256817817687988,
#    0.0729529857635498,
#    0.11013221740722656,
#    0.11068105697631836,
#    0.11044907569885254,
#    0.09612298011779785]},
#  13: {'loss': [1.710124135017395,
#    1.6587852239608765,
#    1.664145827293396,
#    1.497289776802063,
#    1.8535568714141846,
#    1.297213077545166,
#    2.126237630844116,
#    1.7796211242675781,
#    1.6027570962905884,
#    0.9582632184028625,
#    2.360625982284546,
#    1.4711384773254395,
#    1.1453298330307007,
#    1.089693546295166,
#    1.9126225709915161,
#    2.0772557258605957,
#    1.5325971841812134,
#    1.6179591417312622,
#    1.4491162300109863,
#    1.3105586767196655,
#    1.7936301231384277,
#    2.5869569778442383,
#    1.130197286605835,
#    0.7430428862571716,
#    1.9332016706466675,
#    1.558326244354248,
#    1.8850908279418945,
#    1.4641162157058716,
#    1.58902907371521,
#    1.0406262874603271,
#    1.859830379486084,
#    2.5588831901550293,
#    1.4737324714660645,
#    1.2610567808151245,
#    1.2824126482009888,
#    0.8314204812049866,
#    1.6667307615280151,
#    1.541088342666626,
#    1.3881523609161377,
#    1.7339754104614258,
#    2.583350419998169,
#    1.8220233917236328,
#    1.9068812131881714,
#    1.748339295387268,
#    1.6301648616790771,
#    1.389846682548523,
#    2.3115339279174805],
#   'time': [0.09705734252929688,
#    0.09820032119750977,
#    0.09264254570007324,
#    0.08890700340270996,
#    0.08891677856445312,
#    0.10574126243591309,
#    0.10526347160339355,
#    0.09764814376831055,
#    0.10896444320678711,
#    0.11314535140991211,
#    0.11059308052062988,
#    0.1160275936126709,
#    0.10266423225402832,
#    0.10165691375732422,
#    0.1168527603149414,
#    0.1042017936706543,
#    0.10133957862854004,
#    0.1019284725189209,
#    0.11043858528137207,
#    0.08990263938903809,
#    0.07371687889099121,
#    0.07216596603393555,
#    0.0728297233581543,
#    0.07232499122619629,
#    0.0721590518951416,
#    0.08121085166931152,
#    0.07344841957092285,
#    0.07289624214172363,
#    0.07276749610900879,
#    0.07340383529663086,
#    0.07291889190673828,
#    0.07255005836486816,
#    0.07285428047180176,
#    0.07207250595092773,
#    0.07190227508544922,
#    0.07230925559997559,
#    0.07207822799682617,
#    0.07338118553161621,
#    0.0729074478149414,
#    0.08022904396057129,
#    0.07163429260253906,
#    0.07230448722839355,
#    0.07287073135375977,
#    0.07251930236816406,
#    0.07256245613098145,
#    0.07247686386108398,
#    0.07235550880432129]},
#  14: {'loss': [1.77985417842865,
#    1.5669128894805908,
#    1.432551383972168,
#    1.5069622993469238,
#    1.3595377206802368,
#    1.6377969980239868,
#    1.71530282497406,
#    2.9083645343780518,
#    1.9647704362869263,
#    1.3614366054534912,
#    1.7419382333755493,
#    1.2741273641586304,
#    1.5441396236419678,
#    1.791413426399231,
#    1.4334464073181152,
#    2.2214887142181396,
#    1.417412519454956,
#    1.6037224531173706,
#    1.1505603790283203,
#    1.2833062410354614,
#    1.4473081827163696,
#    1.4455870389938354,
#    1.500556468963623,
#    1.1277189254760742,
#    1.124952793121338,
#    2.063493013381958,
#    1.8782010078430176,
#    1.29314386844635,
#    1.072623610496521,
#    1.4652092456817627,
#    1.403971552848816,
#    1.215933084487915,
#    1.9967015981674194,
#    2.0418307781219482,
#    1.6053074598312378,
#    1.5325188636779785,
#    1.4126689434051514,
#    1.412160873413086,
#    1.2235829830169678,
#    1.6268343925476074,
#    1.304447054862976,
#    2.079206943511963,
#    1.2564696073532104,
#    1.4293123483657837,
#    1.6990609169006348,
#    1.6353933811187744,
#    1.6003607511520386],
#   'time': [0.07213401794433594,
#    0.07300114631652832,
#    0.0749664306640625,
#    0.08640432357788086,
#    0.07378935813903809,
#    0.07251381874084473,
#    0.07298135757446289,
#    0.07237029075622559,
#    0.07450628280639648,
#    0.07237815856933594,
#    0.07221388816833496,
#    0.07253146171569824,
#    0.0735771656036377,
#    0.07355046272277832,
#    0.07383084297180176,
#    0.0728142261505127,
#    0.0801076889038086,
#    0.07343864440917969,
#    0.07294726371765137,
#    0.07228660583496094,
#    0.07312655448913574,
#    0.0724020004272461,
#    0.07336640357971191,
#    0.07324743270874023,
#    0.07232856750488281,
#    0.07307672500610352,
#    0.0729219913482666,
#    0.07342028617858887,
#    0.07355833053588867,
#    0.07385039329528809,
#    0.07766890525817871,
#    0.07204627990722656,
#    0.07251834869384766,
#    0.07237529754638672,
#    0.07295632362365723,
#    0.07243752479553223,
#    0.07198858261108398,
#    0.07249212265014648,
#    0.07172393798828125,
#    0.07203316688537598,
#    0.07245349884033203,
#    0.07318663597106934,
#    0.07262063026428223,
#    0.0814361572265625,
#    0.07258439064025879,
#    0.07289600372314453,
#    0.07218408584594727]},
#  15: {'loss': [1.4330511093139648,
#    1.886077880859375,
#    1.7261205911636353,
#    1.6215041875839233,
#    1.2951698303222656,
#    1.550199031829834,
#    1.4494208097457886,
#    1.2436591386795044,
#    1.4433194398880005,
#    1.4269472360610962,
#    2.2344472408294678,
#    1.6824008226394653,
#    1.8546289205551147,
#    2.289215564727783,
#    0.9760815501213074,
#    1.0503212213516235,
#    1.601361870765686,
#    1.6326415538787842,
#    1.5853921175003052,
#    1.6703603267669678,
#    1.602781057357788,
#    1.4038819074630737,
#    1.791554570198059,
#    1.3074557781219482,
#    1.742279291152954,
#    1.0609734058380127,
#    1.8005343675613403,
#    1.836525321006775,
#    1.1748735904693604,
#    2.006155490875244,
#    1.5946292877197266,
#    1.7866885662078857,
#    1.7900023460388184,
#    2.08198881149292,
#    1.228871464729309,
#    2.848395347595215,
#    2.5084989070892334,
#    0.8580737113952637,
#    1.494157314300537,
#    1.4102076292037964,
#    1.3166379928588867,
#    1.7059507369995117,
#    2.847855806350708,
#    1.2232935428619385,
#    1.301640510559082,
#    1.2833590507507324,
#    1.4980052709579468],
#   'time': [0.07252287864685059,
#    0.07249140739440918,
#    0.07378101348876953,
#    0.07261896133422852,
#    0.0743105411529541,
#    0.0729684829711914,
#    0.07484269142150879,
#    0.07770633697509766,
#    0.07272958755493164,
#    0.07293057441711426,
#    0.07267045974731445,
#    0.07311153411865234,
#    0.07233500480651855,
#    0.07200050354003906,
#    0.07228541374206543,
#    0.07364773750305176,
#    0.07235121726989746,
#    0.07187390327453613,
#    0.07254624366760254,
#    0.07437658309936523,
#    0.07230067253112793,
#    0.08147072792053223,
#    0.07270979881286621,
#    0.07155823707580566,
#    0.07229876518249512,
#    0.07354068756103516,
#    0.07246160507202148,
#    0.07177186012268066,
#    0.07384705543518066,
#    0.07281613349914551,
#    0.0717010498046875,
#    0.07223629951477051,
#    0.07579588890075684,
#    0.07278633117675781,
#    0.08277487754821777,
#    0.07479524612426758,
#    0.07291841506958008,
#    0.07232451438903809,
#    0.07368063926696777,
#    0.07278585433959961,
#    0.07252383232116699,
#    0.07323551177978516,
#    0.07234859466552734,
#    0.07372570037841797,
#    0.07388043403625488,
#    0.07450985908508301,
#    0.07351803779602051]},
#  16: {'loss': [0.8243646025657654,
#    1.1430586576461792,
#    0.8278582096099854,
#    0.9937252998352051,
#    1.3087072372436523,
#    1.1074861288070679,
#    1.5645678043365479,
#    1.9159643650054932,
#    1.4784719944000244,
#    1.4712343215942383,
#    1.971484899520874,
#    1.2356510162353516,
#    1.2543995380401611,
#    1.6382968425750732,
#    1.744309902191162,
#    1.4776827096939087,
#    1.5870319604873657,
#    2.3516499996185303,
#    1.564029574394226,
#    1.2960854768753052,
#    1.530786156654358,
#    1.2778244018554688,
#    0.8378486633300781,
#    1.3321969509124756,
#    1.1364951133728027,
#    1.2440123558044434,
#    1.612137794494629,
#    1.7764312028884888,
#    1.0944623947143555,
#    1.7225041389465332,
#    1.0556960105895996,
#    2.1529695987701416,
#    2.0149052143096924,
#    1.3643344640731812,
#    1.0417606830596924,
#    2.046698808670044,
#    1.252984642982483,
#    1.1849476099014282,
#    1.3931552171707153,
#    1.607959270477295,
#    1.1311101913452148,
#    1.3825191259384155,
#    1.225178837776184,
#    1.7937284708023071,
#    1.1247367858886719,
#    1.9311968088150024,
#    2.152852773666382],
#   'time': [0.0726466178894043,
#    0.07243609428405762,
#    0.09556174278259277,
#    0.11019039154052734,
#    0.1137230396270752,
#    0.09647488594055176,
#    0.09794759750366211,
#    0.09350013732910156,
#    0.09412240982055664,
#    0.10036396980285645,
#    0.08941340446472168,
#    0.08925199508666992,
#    0.0884251594543457,
#    0.08838438987731934,
#    0.1076805591583252,
#    0.0943143367767334,
#    0.11420869827270508,
#    0.10549283027648926,
#    0.10846233367919922,
#    0.10796546936035156,
#    0.1018068790435791,
#    0.10195207595825195,
#    0.10052776336669922,
#    0.1031949520111084,
#    0.10096406936645508,
#    0.10394072532653809,
#    0.10568809509277344,
#    0.10818052291870117,
#    0.13868474960327148,
#    0.11031723022460938,
#    0.09473586082458496,
#    0.07555508613586426,
#    0.07470393180847168,
#    0.07244062423706055,
#    0.07345771789550781,
#    0.0738215446472168,
#    0.0758364200592041,
#    0.0724787712097168,
#    0.07272052764892578,
#    0.07270407676696777,
#    0.0727684497833252,
#    0.08037328720092773,
#    0.0738070011138916,
#    0.0727229118347168,
#    0.07278013229370117,
#    0.07432818412780762,
#    0.07469511032104492]},
#  17: {'loss': [1.209663987159729,
#    1.1325427293777466,
#    2.0318055152893066,
#    1.8889479637145996,
#    0.9358488917350769,
#    1.250443935394287,
#    0.8686688542366028,
#    1.3712211847305298,
#    0.963717520236969,
#    0.6848462820053101,
#    1.0451122522354126,
#    0.841741144657135,
#    0.7477722764015198,
#    0.9842672944068909,
#    0.7315607666969299,
#    1.2365769147872925,
#    0.9208059310913086,
#    0.7562705874443054,
#    0.7930764555931091,
#    1.5712729692459106,
#    1.0556005239486694,
#    1.2888625860214233,
#    0.6668636202812195,
#    1.3544937372207642,
#    1.1936192512512207,
#    1.2442063093185425,
#    0.7190678715705872,
#    0.8260058164596558,
#    0.7105963826179504,
#    0.9773833751678467,
#    1.115794062614441,
#    1.2056922912597656,
#    1.2620007991790771,
#    1.1068233251571655,
#    0.9183409214019775,
#    0.9581171870231628,
#    1.0683575868606567,
#    1.2766755819320679,
#    0.9091809988021851,
#    0.6599397659301758,
#    1.1691025495529175,
#    0.9351378679275513,
#    0.9096628427505493,
#    1.067739725112915,
#    1.0422401428222656,
#    1.1738195419311523,
#    1.1144927740097046],
#   'time': [0.07459735870361328,
#    0.07360076904296875,
#    0.0737309455871582,
#    0.07269954681396484,
#    0.07314014434814453,
#    0.07610917091369629,
#    0.0773770809173584,
#    0.0729207992553711,
#    0.07291913032531738,
#    0.07302618026733398,
#    0.07321763038635254,
#    0.07311630249023438,
#    0.07318472862243652,
#    0.07395696640014648,
#    0.07365083694458008,
#    0.07335352897644043,
#    0.07343840599060059,
#    0.0735177993774414,
#    0.07256793975830078,
#    0.0800466537475586,
#    0.07279205322265625,
#    0.07253360748291016,
#    0.07221770286560059,
#    0.07224369049072266,
#    0.07278943061828613,
#    0.07351374626159668,
#    0.07447552680969238,
#    0.07307291030883789,
#    0.07220840454101562,
#    0.07292032241821289,
#    0.07256364822387695,
#    0.07261395454406738,
#    0.08332490921020508,
#    0.07275605201721191,
#    0.07274150848388672,
#    0.07338333129882812,
#    0.07312607765197754,
#    0.07254862785339355,
#    0.07336759567260742,
#    0.07399272918701172,
#    0.07319450378417969,
#    0.07222366333007812,
#    0.0725557804107666,
#    0.07314395904541016,
#    0.07374906539916992,
#    0.07957220077514648,
#    0.07224631309509277]},
#  18: {'loss': [1.0456092357635498,
#    0.5379494428634644,
#    1.0057090520858765,
#    1.5066008567810059,
#    0.5197864770889282,
#    0.832951009273529,
#    0.4988003075122833,
#    1.1154799461364746,
#    0.9154792428016663,
#    0.7543115019798279,
#    0.8894815444946289,
#    1.032850742340088,
#    0.9544214606285095,
#    0.5330871343612671,
#    1.1869018077850342,
#    0.9427316188812256,
#    1.1163579225540161,
#    0.5668947696685791,
#    1.075839638710022,
#    0.6857413053512573,
#    0.9867276549339294,
#    1.0970852375030518,
#    0.7191578149795532,
#    1.0661567449569702,
#    0.9341006278991699,
#    1.013528823852539,
#    1.047783374786377,
#    0.6693884134292603,
#    0.6174095273017883,
#    0.801152765750885,
#    0.9994202852249146,
#    0.7798545360565186,
#    1.0500984191894531,
#    0.8464851379394531,
#    1.0306758880615234,
#    0.5029841065406799,
#    0.6361793279647827,
#    0.8693550229072571,
#    0.8511634469032288,
#    0.9123853445053101,
#    0.8904736042022705,
#    0.8047739267349243,
#    0.8820324540138245,
#    1.1166657209396362,
#    1.0819542407989502,
#    0.840320885181427,
#    1.465946078300476],
#   'time': [0.07436728477478027,
#    0.07263898849487305,
#    0.07272911071777344,
#    0.07375764846801758,
#    0.07232904434204102,
#    0.07264471054077148,
#    0.07244300842285156,
#    0.07254958152770996,
#    0.07398796081542969,
#    0.07393074035644531,
#    0.0806121826171875,
#    0.07208895683288574,
#    0.07225418090820312,
#    0.07306504249572754,
#    0.07271075248718262,
#    0.0727243423461914,
#    0.0730597972869873,
#    0.07241582870483398,
#    0.07239603996276855,
#    0.07247734069824219,
#    0.07268977165222168,
#    0.07220149040222168,
#    0.07302284240722656,
#    0.08149886131286621,
#    0.07328200340270996,
#    0.0733637809753418,
#    0.07396650314331055,
#    0.07362818717956543,
#    0.07426095008850098,
#    0.07444572448730469,
#    0.0728139877319336,
#    0.07270383834838867,
#    0.07416439056396484,
#    0.07279729843139648,
#    0.07327890396118164,
#    0.07291936874389648,
#    0.0818939208984375,
#    0.08029460906982422,
#    0.0739755630493164,
#    0.07327890396118164,
#    0.0744009017944336,
#    0.07542943954467773,
#    0.07408452033996582,
#    0.0729362964630127,
#    0.07230019569396973,
#    0.07302737236022949,
#    0.07339358329772949]},
#  19: {'loss': [0.9161476492881775,
#    0.967430055141449,
#    1.044750690460205,
#    0.6444939970970154,
#    1.0890432596206665,
#    1.085368037223816,
#    0.7204122543334961,
#    0.9700965881347656,
#    0.9161937236785889,
#    0.8273341059684753,
#    0.8162527084350586,
#    0.9027742743492126,
#    0.8386197090148926,
#    0.7288340926170349,
#    0.759009599685669,
#    1.4498498439788818,
#    0.9514462351799011,
#    1.0858205556869507,
#    1.1609270572662354,
#    0.9713149070739746,
#    0.9654259085655212,
#    0.9854726195335388,
#    0.8070345520973206,
#    0.8557500839233398,
#    1.3043509721755981,
#    1.383394479751587,
#    1.045851230621338,
#    1.4359550476074219,
#    0.7302030324935913,
#    1.4444262981414795,
#    0.9917719960212708,
#    2.0188558101654053,
#    2.398026704788208,
#    0.7164263129234314,
#    1.5724695920944214,
#    1.0432122945785522,
#    1.934340000152588,
#    1.8740545511245728,
#    0.8035632371902466,
#    1.5589911937713623,
#    0.951508104801178,
#    0.9945191144943237,
#    0.9449803233146667,
#    0.9548869132995605,
#    1.271504282951355,
#    1.116788625717163,
#    1.3246214389801025],
#   'time': [0.08256649971008301,
#    0.07369184494018555,
#    0.07531976699829102,
#    0.07294297218322754,
#    0.07276129722595215,
#    0.0725257396697998,
#    0.07442164421081543,
#    0.0725555419921875,
#    0.07293128967285156,
#    0.07279539108276367,
#    0.07274389266967773,
#    0.07260990142822266,
#    0.0734395980834961,
#    0.09024715423583984,
#    0.116424560546875,
#    0.11073780059814453,
#    0.10497188568115234,
#    0.09480929374694824,
#    0.09131407737731934,
#    0.0918424129486084,
#    0.0930328369140625,
#    0.08913111686706543,
#    0.0876915454864502,
#    0.0905916690826416,
#    0.09127259254455566,
#    0.10654211044311523,
#    0.0954596996307373,
#    0.11387181282043457,
#    0.10373830795288086,
#    0.1115868091583252,
#    0.10236048698425293,
#    0.10167050361633301,
#    0.10033535957336426,
#    0.11782169342041016,
#    0.10449528694152832,
#    0.10103225708007812,
#    0.1026914119720459,
#    0.10028600692749023,
#    0.12003207206726074,
#    0.10696220397949219,
#    0.10920858383178711,
#    0.10542011260986328,
#    0.07341980934143066,
#    0.08159589767456055,
#    0.07345438003540039,
#    0.07404041290283203,
#    0.07426619529724121]}}

# %%
eval_data
# Out:
# {None: {'loss': 22.085386276245117,
#   'mae_e': 133.8525848388672,
#   'mae_e_per_atom': 4.957502841949463,
#   'rmse_e': 133.85797119140625,
#   'rmse_e_per_atom': 4.95770263671875,
#   'q95_e': 135.066015625,
#   'mae_f': 0.9392006397247314,
#   'rel_mae_f': 100.16345581697108,
#   'rmse_f': 1.2729582786560059,
#   'rel_rmse_f': 100.08878153241207,
#   'q95_f': 2.6899831295013428,
#   'time': 3.4002392292022705},
#  0: {'loss': 4.218286037445068,
#   'mae_e': 78.74624633789062,
#   'mae_e_per_atom': 2.916527509689331,
#   'rmse_e': 78.74710845947266,
#   'rmse_e_per_atom': 2.9165596961975098,
#   'q95_e': 79.126953125,
#   'mae_f': 0.3729008138179779,
#   'rel_mae_f': 39.76896161390683,
#   'rmse_f': 0.5185280442237854,
#   'rel_rmse_f': 40.77026011531058,
#   'q95_f': 1.089206624031067,
#   'time': 0.278454065322876},
#  1: {'loss': 2.2783560752868652,
#   'mae_e': 52.31703186035156,
#   'mae_e_per_atom': 1.937667727470398,
#   'rmse_e': 52.31767654418945,
#   'rmse_e_per_atom': 1.9376916885375977,
#   'q95_e': 52.552734375,
#   'mae_f': 0.2631898522377014,
#   'rel_mae_f': 28.068555344907498,
#   'rmse_f': 0.38897404074668884,
#   'rel_rmse_f': 30.58382858170291,
#   'q95_f': 0.7780969023704526,
#   'time': 1.2084755897521973},
#  2: {'loss': 1.1206287145614624,
#   'mae_e': 31.939062118530273,
#   'mae_e_per_atom': 1.182928204536438,
#   'rmse_e': 31.940370559692383,
#   'rmse_e_per_atom': 1.1829767227172852,
#   'q95_e': 32.221484375,
#   'mae_f': 0.2115902304649353,
#   'rel_mae_f': 22.565581627679542,
#   'rmse_f': 0.2825348377227783,
#   'rel_rmse_f': 22.214842483280187,
#   'q95_f': 0.5518409252166747,
#   'time': 0.09927105903625488},
#  3: {'loss': 0.584744393825531,
#   'mae_e': 17.288047790527344,
#   'mae_e_per_atom': 0.6402980089187622,
#   'rmse_e': 17.289310455322266,
#   'rmse_e_per_atom': 0.6403448581695557,
#   'q95_e': 17.46796875,
#   'mae_f': 0.15259943902492523,
#   'rel_mae_f': 16.274357705875804,
#   'rmse_f': 0.2111118584871292,
#   'rel_rmse_f': 16.599074013115988,
#   'q95_f': 0.429810607433319,
#   'time': 0.10414385795593262},
#  4: {'loss': 0.688234806060791,
#   'mae_e': 9.721327781677246,
#   'mae_e_per_atom': 0.36004921793937683,
#   'rmse_e': 9.722334861755371,
#   'rmse_e_per_atom': 0.36008647084236145,
#   'q95_e': 9.848828125,
#   'mae_f': 0.17109954357147217,
#   'rel_mae_f': 18.2473487005375,
#   'rmse_f': 0.23545987904071808,
#   'rel_rmse_f': 18.513483739495857,
#   'q95_f': 0.49780931472778317,
#   'time': 0.10512471199035645},
#  5: {'loss': 0.3832182288169861,
#   'mae_e': 5.501640796661377,
#   'mae_e_per_atom': 0.20376445353031158,
#   'rmse_e': 5.502697944641113,
#   'rmse_e_per_atom': 0.2038036286830902,
#   'q95_e': 5.630078125,
#   'mae_f': 0.13075962662696838,
#   'rel_mae_f': 13.945195020451282,
#   'rmse_f': 0.17815157771110535,
#   'rel_rmse_f': 14.007508839965569,
#   'q95_f': 0.35272202491760246,
#   'time': 0.10319209098815918},
#  6: {'loss': 0.3158131241798401,
#   'mae_e': 2.842656135559082,
#   'mae_e_per_atom': 0.10528356581926346,
#   'rmse_e': 2.8438611030578613,
#   'rmse_e_per_atom': 0.10532818734645844,
#   'q95_e': 2.93203125,
#   'mae_f': 0.1187770664691925,
#   'rel_mae_f': 12.667284226768952,
#   'rmse_f': 0.1615595519542694,
#   'rel_rmse_f': 12.702929052080098,
#   'q95_f': 0.3201789498329162,
#   'time': 0.160691499710083},
#  7: {'loss': 0.3607015907764435,
#   'mae_e': 3.5628905296325684,
#   'mae_e_per_atom': 0.13195890188217163,
#   'rmse_e': 3.5637505054473877,
#   'rmse_e_per_atom': 0.13199076056480408,
#   'q95_e': 3.648046875,
#   'mae_f': 0.11968828737735748,
#   'rel_mae_f': 12.764463712508265,
#   'rmse_f': 0.17271380126476288,
#   'rel_rmse_f': 13.579953257126906,
#   'q95_f': 0.38043303489685054,
#   'time': 0.10953998565673828},
#  8: {'loss': 0.27383506298065186,
#   'mae_e': 1.7848438024520874,
#   'mae_e_per_atom': 0.06610532104969025,
#   'rmse_e': 1.7868233919143677,
#   'rmse_e_per_atom': 0.06617864221334457,
#   'q95_e': 1.898046875,
#   'mae_f': 0.10936860740184784,
#   'rel_mae_f': 11.66389503149119,
#   'rmse_f': 0.1515793800354004,
#   'rel_rmse_f': 11.918218929531351,
#   'q95_f': 0.292122745513916,
#   'time': 0.10334539413452148},
#  9: {'loss': 0.326456218957901,
#   'mae_e': 0.5446093678474426,
#   'mae_e_per_atom': 0.02017071656882763,
#   'rmse_e': 0.5513327121734619,
#   'rmse_e_per_atom': 0.020419729873538017,
#   'q95_e': 0.658203125,
#   'mae_f': 0.12402006983757019,
#   'rel_mae_f': 13.226437738834965,
#   'rmse_f': 0.16560907661914825,
#   'rel_rmse_f': 13.021330681017302,
#   'q95_f': 0.3265026569366455,
#   'time': 0.15327882766723633},
#  10: {'loss': 0.256435364484787,
#   'mae_e': 1.5780469179153442,
#   'mae_e_per_atom': 0.05844618007540703,
#   'rmse_e': 1.5791101455688477,
#   'rmse_e_per_atom': 0.05848556011915207,
#   'q95_e': 1.671484375,
#   'mae_f': 0.10593417286872864,
#   'rel_mae_f': 11.297620971333831,
#   'rmse_f': 0.14747048914432526,
#   'rel_rmse_f': 11.595149517412409,
#   'q95_f': 0.2960948586463928,
#   'time': 0.09934496879577637},
#  11: {'loss': 0.2590709924697876,
#   'mae_e': 3.0610156059265137,
#   'mae_e_per_atom': 0.11337096244096756,
#   'rmse_e': 3.0620782375335693,
#   'rmse_e_per_atom': 0.11341030150651932,
#   'q95_e': 3.1937499999999996,
#   'mae_f': 0.1040799468755722,
#   'rel_mae_f': 11.099872294975777,
#   'rmse_f': 0.14684610068798065,
#   'rel_rmse_f': 11.546055779741431,
#   'q95_f': 0.30059998035430907,
#   'time': 0.10026860237121582},
#  12: {'loss': 0.22136367857456207,
#   'mae_e': 2.298593759536743,
#   'mae_e_per_atom': 0.08513309806585312,
#   'rmse_e': 2.2998011112213135,
#   'rmse_e_per_atom': 0.08517781645059586,
#   'q95_e': 2.4226562499999997,
#   'mae_f': 0.09987498819828033,
#   'rel_mae_f': 10.651423715544915,
#   'rmse_f': 0.1359470933675766,
#   'rel_rmse_f': 10.68910046478498,
#   'q95_f': 0.2716012954711914,
#   'time': 0.1325523853302002},
#  13: {'loss': 0.20226769149303436,
#   'mae_e': 0.20546874403953552,
#   'mae_e_per_atom': 0.0076099541038274765,
#   'rmse_e': 0.21116885542869568,
#   'rmse_e_per_atom': 0.007821069099009037,
#   'q95_e': 0.3058593749999998,
#   'mae_f': 0.09864215552806854,
#   'rel_mae_f': 10.519945120376294,
#   'rmse_f': 0.1310676485300064,
#   'rel_rmse_f': 10.305444773521751,
#   'q95_f': 0.24713329076766966,
#   'time': 0.10331606864929199},
#  14: {'loss': 0.18774141371250153,
#   'mae_e': 1.255859375,
#   'mae_e_per_atom': 0.046513307839632034,
#   'rmse_e': 1.2568756341934204,
#   'rmse_e_per_atom': 0.04655095189809799,
#   'q95_e': 1.3148437499999999,
#   'mae_f': 0.08711513876914978,
#   'rel_mae_f': 9.290616918287505,
#   'rmse_f': 0.12521784007549286,
#   'rel_rmse_f': 9.84549238527189,
#   'q95_f': 0.24886832237243647,
#   'time': 0.10145878791809082},
#  15: {'loss': 0.1537495255470276,
#   'mae_e': 0.38039061427116394,
#   'mae_e_per_atom': 0.014088541269302368,
#   'rmse_e': 0.38330981135368347,
#   'rmse_e_per_atom': 0.014196660369634628,
#   'q95_e': 0.461328125,
#   'mae_f': 0.08054258674383163,
#   'rel_mae_f': 8.589670287133542,
#   'rmse_f': 0.11408305168151855,
#   'rel_rmse_f': 8.969998332041182,
#   'q95_f': 0.23213934898376462,
#   'time': 0.11305713653564453},
#  16: {'loss': 0.1813262403011322,
#   'mae_e': 0.643750011920929,
#   'mae_e_per_atom': 0.023842595517635345,
#   'rmse_e': 0.6462347507476807,
#   'rmse_e_per_atom': 0.02393462136387825,
#   'q95_e': 0.7261718749999999,
#   'mae_f': 0.09227634221315384,
#   'rel_mae_f': 9.841046668077087,
#   'rmse_f': 0.12422385066747665,
#   'rel_rmse_f': 9.76733806523439,
#   'q95_f': 0.240821236371994,
#   'time': 0.10195469856262207},
#  17: {'loss': 0.13194170594215393,
#   'mae_e': 1.3527343273162842,
#   'mae_e_per_atom': 0.050101276487112045,
#   'rmse_e': 1.3535703420639038,
#   'rmse_e_per_atom': 0.050132233649492264,
#   'q95_e': 1.408203125,
#   'mae_f': 0.07144688814878464,
#   'rel_mae_f': 7.619636232837651,
#   'rmse_f': 0.10497481375932693,
#   'rel_rmse_f': 8.253845689158045,
#   'q95_f': 0.2106681704521179,
#   'time': 0.09961676597595215},
#  18: {'loss': 0.1098528653383255,
#   'mae_e': 0.5660937428474426,
#   'mae_e_per_atom': 0.020966434851288795,
#   'rmse_e': 0.5672560930252075,
#   'rmse_e_per_atom': 0.02100948616862297,
#   'q95_e': 0.61015625,
#   'mae_f': 0.06232532486319542,
#   'rel_mae_f': 6.646843772426209,
#   'rmse_f': 0.09541048109531403,
#   'rel_rmse_f': 7.501831724079469,
#   'q95_f': 0.18779821395874022,
#   'time': 0.10123872756958008},
#  19: {'loss': 0.12763553857803345,
#   'mae_e': 1.560390591621399,
#   'mae_e_per_atom': 0.05779225006699562,
#   'rmse_e': 1.5609692335128784,
#   'rmse_e_per_atom': 0.057813674211502075,
#   'q95_e': 1.607421875,
#   'mae_f': 0.07588659226894379,
#   'rel_mae_f': 8.093119840781444,
#   'rmse_f': 0.10366540402173996,
#   'rel_rmse_f': 8.150890841886753,
#   'q95_f': 0.19797978997230523,
#   'time': 0.10463476181030273}}

# %% [markdown]
# The `..._train.txt` file contains two types of data:
#
# 1. Optimization Data: Batch Optimization data
# 2. Evaluation Data: Validation data

# %%
train_loss_data = []
valid_loss_data = []

for epoch in opt_data.keys():
  train_loss_data.append(opt_data[epoch]['loss'])
  valid_loss_data.append(eval_data[epoch]['loss'])

average_train_loss_data=[]

num_validation_configs = parameters_mace['valid_fraction'] * num_configs
num_train_configs = num_configs - num_validation_configs

for loss in train_loss_data:
  average_train_loss_data.append(np.sum(loss) / num_train_configs)

plt.plot(valid_loss_data, marker='v', linestyle='-', label='validation_loss')
plt.plot(average_train_loss_data, marker='o', linestyle='-', label='training_loss')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.title('MACE Training')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3.5. Molecular Dynamics using MACE <a name="mace-md"></a>

# %% [markdown]
# #### 3.5.1 MACE Calculator
# MACE models can run molecular dynamics or geometry optimisation through the ASE calculator. There is no need for model deployement unlike in NequIP.

# %%
init_conf = read('./BOTNet-datasets/dataset_3BPA/test_1200K.xyz', index=0)
init_conf
# Out:
# Atoms(symbols='C3HCON2H2CH2C2H2C3HCHCH3', pbc=False, cell=[50.0, 50.0, 50.0], calculator=SinglePointCalculator(...))

# %%
from mace.calculators import MACECalculator

# Specify the path to the pre-trained MACE model
mace_model = mace_train_dir / f"{parameters_mace['name']}_compiled.model"

# Initialize the MACE calculator with the specified model
mace_calc = MACECalculator(model_paths=[mace_model], device='cuda', default_dtype="float32")

# Call the simpleMD function to perform a molecular dynamics simulation
simpleMD(init_conf, temp=1200, calc=mace_calc, fname='mace/results/mace01_md.xyz', s=10, T=1000)
# Out:
# MD finished in 1.30 minutes!

# %% [markdown]
# ## 4. Exercises <a name="exercises"></a>
#
# 1. We haven't tested the trained NequIP or MACE model. To test it we can use:
#
#   - Use `nequip-evaluate` for NequIP model. [Refer this](https://github.com/mir-group/nequip?tab=readme-ov-file#evaluating-trained-models-and-their-error) or use `nequip-evaluate --help` for more reference.
#   - Use `eval_configs.py` for MACE model. [Refer this](https://mace-docs.readthedocs.io/en/latest/guide/evaluation.html).
#
# 2. Play with the hyperparamters for NequIP and MACE. How are they similar? What are the differences in the models?
#
# 3. Training was done on `train_mixedT.xyz`. If you see the `dataset_3BPA` directory, there are other training datasets. Train it on `train_1200K.xyz` and evaluation and MD on `test_1200K.xyz`. Compare the results from tutorials.

# %% [markdown]
# # 5. BONUS: Visualizing `.xyz` files <a name="ovito"></a>
#
# We can visualize the Molecular Dynamics file using softwares such as [OVITO](https://www.ovito.org/).
#
# 1. This can be done by downloading and installing OVITO software on your local device from the following website - [Download OVITO](https://www.ovito.org/#download)
#
# 2. After downloading it, open the application. [Refer this for usage instructions](https://www.ovito.org/manual).
#
# 3. Download `.xyz` trajectory files to your local device.
#
# 4. Go to `Files`->`Load File...`->Load the Trajectory File.
#
# 5. Play the animation.
